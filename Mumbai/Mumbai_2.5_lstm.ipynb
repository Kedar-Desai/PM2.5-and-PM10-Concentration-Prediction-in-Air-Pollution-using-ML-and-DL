# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Mumbai_LSTM_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 938/938 - 5s - loss: 0.0139 - 5s/epoch - 5ms/step
# Epoch 2/100
# 938/938 - 3s - loss: 6.7663e-04 - 3s/epoch - 3ms/step
# Epoch 3/100
# 938/938 - 3s - loss: 5.6863e-04 - 3s/epoch - 3ms/step
# Epoch 4/100
# 938/938 - 3s - loss: 5.5109e-04 - 3s/epoch - 3ms/step
# Epoch 5/100
# 938/938 - 3s - loss: 4.6569e-04 - 3s/epoch - 4ms/step
# Epoch 6/100
# 938/938 - 3s - loss: 5.3443e-04 - 3s/epoch - 4ms/step
# Epoch 7/100
# 938/938 - 3s - loss: 4.0612e-04 - 3s/epoch - 4ms/step
# Epoch 8/100
# 938/938 - 3s - loss: 2.8696e-04 - 3s/epoch - 4ms/step
# Epoch 9/100
# 938/938 - 3s - loss: 3.1652e-04 - 3s/epoch - 4ms/step
# Epoch 10/100
# 938/938 - 3s - loss: 2.6915e-04 - 3s/epoch - 4ms/step
# Epoch 11/100
# 938/938 - 3s - loss: 2.7185e-04 - 3s/epoch - 4ms/step
# Epoch 12/100
# 938/938 - 3s - loss: 2.9519e-04 - 3s/epoch - 4ms/step
# Epoch 13/100
# 938/938 - 3s - loss: 2.6883e-04 - 3s/epoch - 4ms/step
# Epoch 14/100
# 938/938 - 4s - loss: 2.6486e-04 - 4s/epoch - 4ms/step
# Epoch 15/100
# 938/938 - 3s - loss: 2.1188e-04 - 3s/epoch - 4ms/step
# Epoch 16/100
# 938/938 - 3s - loss: 2.3230e-04 - 3s/epoch - 4ms/step
# Epoch 17/100
# 938/938 - 3s - loss: 2.4714e-04 - 3s/epoch - 4ms/step
# Epoch 18/100
# 938/938 - 3s - loss: 2.6459e-04 - 3s/epoch - 4ms/step
# Epoch 19/100
# 938/938 - 4s - loss: 2.9924e-04 - 4s/epoch - 4ms/step
# Epoch 20/100
# 938/938 - 3s - loss: 2.3213e-04 - 3s/epoch - 4ms/step
# Epoch 21/100
# 938/938 - 3s - loss: 2.2076e-04 - 3s/epoch - 4ms/step
# Epoch 22/100
# 938/938 - 3s - loss: 2.1519e-04 - 3s/epoch - 4ms/step
# Epoch 23/100
# 938/938 - 3s - loss: 2.5421e-04 - 3s/epoch - 4ms/step
# Epoch 24/100
# 938/938 - 3s - loss: 2.4138e-04 - 3s/epoch - 3ms/step
# Epoch 25/100
# 938/938 - 3s - loss: 2.2472e-04 - 3s/epoch - 3ms/step
# Epoch 26/100
# 938/938 - 3s - loss: 1.8990e-04 - 3s/epoch - 3ms/step
# Epoch 27/100
# 938/938 - 3s - loss: 2.2647e-04 - 3s/epoch - 4ms/step
# Epoch 28/100
# 938/938 - 4s - loss: 2.3560e-04 - 4s/epoch - 4ms/step
# Epoch 29/100
# 938/938 - 3s - loss: 2.6403e-04 - 3s/epoch - 4ms/step
# Epoch 30/100
# 938/938 - 3s - loss: 2.4197e-04 - 3s/epoch - 3ms/step
# Epoch 31/100
# 938/938 - 3s - loss: 2.7279e-04 - 3s/epoch - 3ms/step
# Epoch 32/100
# 938/938 - 3s - loss: 2.6099e-04 - 3s/epoch - 3ms/step
# Epoch 33/100
# 938/938 - 3s - loss: 2.0402e-04 - 3s/epoch - 3ms/step
# Epoch 34/100
# 938/938 - 3s - loss: 2.1572e-04 - 3s/epoch - 3ms/step
# Epoch 35/100
# 938/938 - 4s - loss: 2.5209e-04 - 4s/epoch - 4ms/step
# Epoch 36/100
# 938/938 - 4s - loss: 2.4914e-04 - 4s/epoch - 4ms/step
# Epoch 37/100
# 938/938 - 4s - loss: 2.6257e-04 - 4s/epoch - 4ms/step
# Epoch 38/100
# 938/938 - 3s - loss: 2.4201e-04 - 3s/epoch - 3ms/step
# Epoch 39/100
# 938/938 - 3s - loss: 1.9758e-04 - 3s/epoch - 4ms/step
# Epoch 40/100
# 938/938 - 3s - loss: 2.3010e-04 - 3s/epoch - 4ms/step
# Epoch 41/100
# 938/938 - 3s - loss: 2.5760e-04 - 3s/epoch - 4ms/step
# Epoch 42/100
# 938/938 - 3s - loss: 2.0869e-04 - 3s/epoch - 4ms/step
# Epoch 43/100
# 938/938 - 3s - loss: 2.0389e-04 - 3s/epoch - 3ms/step
# Epoch 44/100
# 938/938 - 4s - loss: 2.1002e-04 - 4s/epoch - 4ms/step
# Epoch 45/100
# 938/938 - 4s - loss: 2.3681e-04 - 4s/epoch - 4ms/step
# Epoch 46/100
# 938/938 - 4s - loss: 2.4214e-04 - 4s/epoch - 4ms/step
# Epoch 47/100
# 938/938 - 3s - loss: 2.2970e-04 - 3s/epoch - 4ms/step
# Epoch 48/100
# 938/938 - 4s - loss: 2.1442e-04 - 4s/epoch - 4ms/step
# Epoch 49/100
# 938/938 - 4s - loss: 2.2735e-04 - 4s/epoch - 4ms/step
# Epoch 50/100
# 938/938 - 4s - loss: 2.4443e-04 - 4s/epoch - 4ms/step
# Epoch 51/100
# 938/938 - 4s - loss: 1.9327e-04 - 4s/epoch - 4ms/step
# Epoch 52/100
# 938/938 - 4s - loss: 2.5838e-04 - 4s/epoch - 4ms/step
# Epoch 53/100
# 938/938 - 4s - loss: 2.1042e-04 - 4s/epoch - 4ms/step
# Epoch 54/100
# 938/938 - 4s - loss: 2.1390e-04 - 4s/epoch - 4ms/step
# Epoch 55/100
# 938/938 - 4s - loss: 2.2327e-04 - 4s/epoch - 4ms/step
# Epoch 56/100
# 938/938 - 4s - loss: 2.0107e-04 - 4s/epoch - 4ms/step
# Epoch 57/100
# 938/938 - 4s - loss: 2.1530e-04 - 4s/epoch - 4ms/step
# Epoch 58/100
# 938/938 - 4s - loss: 2.3710e-04 - 4s/epoch - 4ms/step
# Epoch 59/100
# 938/938 - 4s - loss: 2.0387e-04 - 4s/epoch - 4ms/step
# Epoch 60/100
# 938/938 - 4s - loss: 2.5187e-04 - 4s/epoch - 4ms/step
# Epoch 61/100
# 938/938 - 4s - loss: 2.2630e-04 - 4s/epoch - 4ms/step
# Epoch 62/100
# 938/938 - 5s - loss: 2.2361e-04 - 5s/epoch - 5ms/step
# Epoch 63/100
# 938/938 - 6s - loss: 2.3217e-04 - 6s/epoch - 7ms/step
# Epoch 64/100
# 938/938 - 4s - loss: 2.3805e-04 - 4s/epoch - 5ms/step
# Epoch 65/100
# 938/938 - 5s - loss: 1.9448e-04 - 5s/epoch - 5ms/step
# Epoch 66/100
# 938/938 - 5s - loss: 2.2787e-04 - 5s/epoch - 6ms/step
# Epoch 67/100
# 938/938 - 4s - loss: 2.3565e-04 - 4s/epoch - 4ms/step
# Epoch 68/100
# 938/938 - 4s - loss: 2.4009e-04 - 4s/epoch - 4ms/step
# Epoch 69/100
# 938/938 - 4s - loss: 2.2718e-04 - 4s/epoch - 4ms/step
# Epoch 70/100
# 938/938 - 4s - loss: 1.9456e-04 - 4s/epoch - 4ms/step
# Epoch 71/100
# 938/938 - 4s - loss: 2.2855e-04 - 4s/epoch - 4ms/step
# Epoch 72/100
# 938/938 - 5s - loss: 2.0774e-04 - 5s/epoch - 5ms/step
# Epoch 73/100
# 938/938 - 4s - loss: 2.2288e-04 - 4s/epoch - 4ms/step
# Epoch 74/100
# 938/938 - 4s - loss: 2.2285e-04 - 4s/epoch - 5ms/step
# Epoch 75/100
# 938/938 - 4s - loss: 2.3995e-04 - 4s/epoch - 4ms/step
# Epoch 76/100
# 938/938 - 4s - loss: 2.1900e-04 - 4s/epoch - 4ms/step
# Epoch 77/100
# 938/938 - 4s - loss: 2.6000e-04 - 4s/epoch - 4ms/step
# Epoch 78/100
# 938/938 - 4s - loss: 2.1722e-04 - 4s/epoch - 4ms/step
# Epoch 79/100
# 938/938 - 4s - loss: 2.1207e-04 - 4s/epoch - 4ms/step
# Epoch 80/100
# 938/938 - 4s - loss: 2.0125e-04 - 4s/epoch - 4ms/step
# Epoch 81/100
# 938/938 - 4s - loss: 2.2895e-04 - 4s/epoch - 4ms/step
# Epoch 82/100
# 938/938 - 4s - loss: 2.1005e-04 - 4s/epoch - 4ms/step
# Epoch 83/100
# 938/938 - 4s - loss: 2.1034e-04 - 4s/epoch - 4ms/step
# Epoch 84/100
# 938/938 - 4s - loss: 2.3313e-04 - 4s/epoch - 4ms/step
# Epoch 85/100
# 938/938 - 4s - loss: 2.1772e-04 - 4s/epoch - 4ms/step
# Epoch 86/100
# 938/938 - 4s - loss: 2.2680e-04 - 4s/epoch - 4ms/step
# Epoch 87/100
# 938/938 - 4s - loss: 1.9178e-04 - 4s/epoch - 4ms/step
# Epoch 88/100
# 938/938 - 4s - loss: 2.2268e-04 - 4s/epoch - 4ms/step
# Epoch 89/100
# 938/938 - 4s - loss: 2.1536e-04 - 4s/epoch - 4ms/step
# Epoch 90/100
# 938/938 - 4s - loss: 2.7697e-04 - 4s/epoch - 4ms/step
# Epoch 91/100
# 938/938 - 4s - loss: 2.1774e-04 - 4s/epoch - 4ms/step
# Epoch 92/100
# 938/938 - 4s - loss: 2.1119e-04 - 4s/epoch - 4ms/step
# Epoch 93/100
# 938/938 - 4s - loss: 2.4196e-04 - 4s/epoch - 4ms/step
# Epoch 94/100
# 938/938 - 4s - loss: 2.1683e-04 - 4s/epoch - 4ms/step
# Epoch 95/100
# 938/938 - 4s - loss: 2.2569e-04 - 4s/epoch - 4ms/step
# Epoch 96/100
# 938/938 - 4s - loss: 2.1025e-04 - 4s/epoch - 4ms/step
# Epoch 97/100
# 938/938 - 3s - loss: 2.4195e-04 - 3s/epoch - 4ms/step
# Epoch 98/100
# 938/938 - 4s - loss: 2.3231e-04 - 4s/epoch - 4ms/step
# Epoch 99/100
# 938/938 - 4s - loss: 1.8862e-04 - 4s/epoch - 4ms/step
# Epoch 100/100
# 938/938 - 4s - loss: 2.1045e-04 - 4s/epoch - 4ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 30/30 [==============================] - 1s 3ms/step
# 15/15 [==============================] - 0s 2ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 2.11
# Test RMSE: 2.18

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_2.5.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [43.72922897338867]   [41.56471633911133]
# 1     [43.72922897338867]   [41.56471633911133]
# 2     [43.72922897338867]   [41.56471633911133]
# 3     [43.72922897338867]   [41.56471633911133]
# 4     [43.72922897338867]   [41.56471633911133]
# ..                    ...                   ...
# 933  [118.06999969482422]  [114.66722869873047]
# 934  [126.55000305175781]   [122.9317626953125]
# 935  [132.22999572753906]   [128.4454345703125]
# 936   [108.7300033569336]  [105.52616882324219]
# 937  [57.650001525878906]  [55.229026794433594]
#
# [938 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lastm_2.5_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [64.30999755859375]   [61.78498077392578]
# 1    [100.80000305175781]   [97.74008178710938]
# 2     [106.4000015258789]  [103.24054718017578]
# 3     [96.51000213623047]   [93.52053833007812]
# 4     [59.09000015258789]   [56.64573669433594]
# ..                    ...                   ...
# 457  [33.689998626708984]  [31.757831573486328]
# 458  [39.560001373291016]   [37.48628234863281]
# 459   [36.15999984741211]   [34.16619110107422]
# 460   [23.62999725341797]  [21.984024047851562]
# 461  [17.530000686645508]  [16.088581085205078]
#
# [462 rows x 2 columns]

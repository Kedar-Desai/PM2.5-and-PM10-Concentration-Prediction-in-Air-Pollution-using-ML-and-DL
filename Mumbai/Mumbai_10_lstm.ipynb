# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Mumbai_LSTM_10.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 938/938 - 7s - loss: 0.0017 - 7s/epoch - 8ms/step
# Epoch 2/100
# 938/938 - 4s - loss: 1.2764e-04 - 4s/epoch - 4ms/step
# Epoch 3/100
# 938/938 - 4s - loss: 1.1627e-04 - 4s/epoch - 4ms/step
# Epoch 4/100
# 938/938 - 3s - loss: 7.8846e-05 - 3s/epoch - 3ms/step
# Epoch 5/100
# 938/938 - 3s - loss: 7.6393e-05 - 3s/epoch - 4ms/step
# Epoch 6/100
# 938/938 - 3s - loss: 5.6057e-05 - 3s/epoch - 4ms/step
# Epoch 7/100
# 938/938 - 3s - loss: 6.9172e-05 - 3s/epoch - 3ms/step
# Epoch 8/100
# 938/938 - 3s - loss: 5.2926e-05 - 3s/epoch - 4ms/step
# Epoch 9/100
# 938/938 - 3s - loss: 5.2980e-05 - 3s/epoch - 3ms/step
# Epoch 10/100
# 938/938 - 4s - loss: 5.1265e-05 - 4s/epoch - 4ms/step
# Epoch 11/100
# 938/938 - 4s - loss: 4.4987e-05 - 4s/epoch - 4ms/step
# Epoch 12/100
# 938/938 - 4s - loss: 4.9612e-05 - 4s/epoch - 4ms/step
# Epoch 13/100
# 938/938 - 4s - loss: 4.2944e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 938/938 - 4s - loss: 4.8817e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 938/938 - 4s - loss: 4.3324e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 938/938 - 4s - loss: 4.0066e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 938/938 - 4s - loss: 4.7976e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 938/938 - 4s - loss: 4.8098e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 938/938 - 4s - loss: 4.0199e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 938/938 - 4s - loss: 4.9969e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 938/938 - 4s - loss: 4.9094e-05 - 4s/epoch - 4ms/step
# Epoch 22/100
# 938/938 - 4s - loss: 3.8810e-05 - 4s/epoch - 4ms/step
# Epoch 23/100
# 938/938 - 4s - loss: 3.9262e-05 - 4s/epoch - 4ms/step
# Epoch 24/100
# 938/938 - 4s - loss: 4.5386e-05 - 4s/epoch - 4ms/step
# Epoch 25/100
# 938/938 - 4s - loss: 4.3567e-05 - 4s/epoch - 4ms/step
# Epoch 26/100
# 938/938 - 4s - loss: 4.5246e-05 - 4s/epoch - 4ms/step
# Epoch 27/100
# 938/938 - 4s - loss: 4.5171e-05 - 4s/epoch - 4ms/step
# Epoch 28/100
# 938/938 - 5s - loss: 4.3528e-05 - 5s/epoch - 5ms/step
# Epoch 29/100
# 938/938 - 5s - loss: 4.3578e-05 - 5s/epoch - 6ms/step
# Epoch 30/100
# 938/938 - 5s - loss: 3.7461e-05 - 5s/epoch - 6ms/step
# Epoch 31/100
# 938/938 - 4s - loss: 4.0646e-05 - 4s/epoch - 5ms/step
# Epoch 32/100
# 938/938 - 6s - loss: 3.7198e-05 - 6s/epoch - 6ms/step
# Epoch 33/100
# 938/938 - 4s - loss: 4.2604e-05 - 4s/epoch - 4ms/step
# Epoch 34/100
# 938/938 - 4s - loss: 3.8966e-05 - 4s/epoch - 4ms/step
# Epoch 35/100
# 938/938 - 4s - loss: 4.2879e-05 - 4s/epoch - 4ms/step
# Epoch 36/100
# 938/938 - 4s - loss: 4.8171e-05 - 4s/epoch - 4ms/step
# Epoch 37/100
# 938/938 - 4s - loss: 4.2841e-05 - 4s/epoch - 4ms/step
# Epoch 38/100
# 938/938 - 4s - loss: 4.0719e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 938/938 - 5s - loss: 3.8279e-05 - 5s/epoch - 5ms/step
# Epoch 40/100
# 938/938 - 4s - loss: 4.8562e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 938/938 - 4s - loss: 4.5376e-05 - 4s/epoch - 5ms/step
# Epoch 42/100
# 938/938 - 4s - loss: 3.9734e-05 - 4s/epoch - 4ms/step
# Epoch 43/100
# 938/938 - 4s - loss: 4.3122e-05 - 4s/epoch - 4ms/step
# Epoch 44/100
# 938/938 - 4s - loss: 4.0740e-05 - 4s/epoch - 4ms/step
# Epoch 45/100
# 938/938 - 4s - loss: 4.5828e-05 - 4s/epoch - 4ms/step
# Epoch 46/100
# 938/938 - 4s - loss: 4.2953e-05 - 4s/epoch - 4ms/step
# Epoch 47/100
# 938/938 - 4s - loss: 3.7418e-05 - 4s/epoch - 4ms/step
# Epoch 48/100
# 938/938 - 4s - loss: 3.8660e-05 - 4s/epoch - 4ms/step
# Epoch 49/100
# 938/938 - 4s - loss: 4.3052e-05 - 4s/epoch - 4ms/step
# Epoch 50/100
# 938/938 - 4s - loss: 4.3243e-05 - 4s/epoch - 4ms/step
# Epoch 51/100
# 938/938 - 4s - loss: 4.1606e-05 - 4s/epoch - 4ms/step
# Epoch 52/100
# 938/938 - 4s - loss: 4.1243e-05 - 4s/epoch - 4ms/step
# Epoch 53/100
# 938/938 - 4s - loss: 4.1967e-05 - 4s/epoch - 4ms/step
# Epoch 54/100
# 938/938 - 4s - loss: 4.5455e-05 - 4s/epoch - 4ms/step
# Epoch 55/100
# 938/938 - 4s - loss: 3.8919e-05 - 4s/epoch - 4ms/step
# Epoch 56/100
# 938/938 - 4s - loss: 4.8301e-05 - 4s/epoch - 4ms/step
# Epoch 57/100
# 938/938 - 4s - loss: 4.4010e-05 - 4s/epoch - 4ms/step
# Epoch 58/100
# 938/938 - 3s - loss: 4.1552e-05 - 3s/epoch - 4ms/step
# Epoch 59/100
# 938/938 - 4s - loss: 4.0138e-05 - 4s/epoch - 4ms/step
# Epoch 60/100
# 938/938 - 4s - loss: 4.1087e-05 - 4s/epoch - 4ms/step
# Epoch 61/100
# 938/938 - 4s - loss: 4.1978e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 938/938 - 4s - loss: 3.5844e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 938/938 - 4s - loss: 4.4707e-05 - 4s/epoch - 4ms/step
# Epoch 64/100
# 938/938 - 3s - loss: 3.5330e-05 - 3s/epoch - 4ms/step
# Epoch 65/100
# 938/938 - 4s - loss: 4.2067e-05 - 4s/epoch - 4ms/step
# Epoch 66/100
# 938/938 - 4s - loss: 4.3115e-05 - 4s/epoch - 4ms/step
# Epoch 67/100
# 938/938 - 4s - loss: 3.8459e-05 - 4s/epoch - 4ms/step
# Epoch 68/100
# 938/938 - 3s - loss: 4.8079e-05 - 3s/epoch - 4ms/step
# Epoch 69/100
# 938/938 - 4s - loss: 4.2249e-05 - 4s/epoch - 4ms/step
# Epoch 70/100
# 938/938 - 3s - loss: 4.1889e-05 - 3s/epoch - 3ms/step
# Epoch 71/100
# 938/938 - 3s - loss: 4.1597e-05 - 3s/epoch - 3ms/step
# Epoch 72/100
# 938/938 - 3s - loss: 4.3381e-05 - 3s/epoch - 4ms/step
# Epoch 73/100
# 938/938 - 3s - loss: 3.7015e-05 - 3s/epoch - 3ms/step
# Epoch 74/100
# 938/938 - 3s - loss: 4.1593e-05 - 3s/epoch - 3ms/step
# Epoch 75/100
# 938/938 - 3s - loss: 3.8297e-05 - 3s/epoch - 3ms/step
# Epoch 76/100
# 938/938 - 3s - loss: 4.2696e-05 - 3s/epoch - 3ms/step
# Epoch 77/100
# 938/938 - 3s - loss: 4.2004e-05 - 3s/epoch - 4ms/step
# Epoch 78/100
# 938/938 - 4s - loss: 4.5325e-05 - 4s/epoch - 4ms/step
# Epoch 79/100
# 938/938 - 3s - loss: 4.0676e-05 - 3s/epoch - 3ms/step
# Epoch 80/100
# 938/938 - 3s - loss: 3.9010e-05 - 3s/epoch - 3ms/step
# Epoch 81/100
# 938/938 - 3s - loss: 4.4100e-05 - 3s/epoch - 3ms/step
# Epoch 82/100
# 938/938 - 4s - loss: 3.3808e-05 - 4s/epoch - 4ms/step
# Epoch 83/100
# 938/938 - 4s - loss: 3.8286e-05 - 4s/epoch - 5ms/step
# Epoch 84/100
# 938/938 - 5s - loss: 4.3555e-05 - 5s/epoch - 6ms/step
# Epoch 85/100
# 938/938 - 4s - loss: 3.4380e-05 - 4s/epoch - 4ms/step
# Epoch 86/100
# 938/938 - 4s - loss: 4.3837e-05 - 4s/epoch - 5ms/step
# Epoch 87/100
# 938/938 - 5s - loss: 3.7674e-05 - 5s/epoch - 6ms/step
# Epoch 88/100
# 938/938 - 4s - loss: 4.9396e-05 - 4s/epoch - 4ms/step
# Epoch 89/100
# 938/938 - 4s - loss: 3.6176e-05 - 4s/epoch - 5ms/step
# Epoch 90/100
# 938/938 - 3s - loss: 4.0826e-05 - 3s/epoch - 3ms/step
# Epoch 91/100
# 938/938 - 3s - loss: 4.1504e-05 - 3s/epoch - 3ms/step
# Epoch 92/100
# 938/938 - 3s - loss: 3.9431e-05 - 3s/epoch - 3ms/step
# Epoch 93/100
# 938/938 - 3s - loss: 3.9034e-05 - 3s/epoch - 3ms/step
# Epoch 94/100
# 938/938 - 3s - loss: 3.4443e-05 - 3s/epoch - 3ms/step
# Epoch 95/100
# 938/938 - 3s - loss: 4.3895e-05 - 3s/epoch - 3ms/step
# Epoch 96/100
# 938/938 - 3s - loss: 4.1216e-05 - 3s/epoch - 3ms/step
# Epoch 97/100
# 938/938 - 3s - loss: 3.9536e-05 - 3s/epoch - 3ms/step
# Epoch 98/100
# 938/938 - 3s - loss: 4.2968e-05 - 3s/epoch - 3ms/step
# Epoch 99/100
# 938/938 - 3s - loss: 3.8826e-05 - 3s/epoch - 3ms/step
# Epoch 100/100
# 938/938 - 3s - loss: 3.9487e-05 - 3s/epoch - 3ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 30/30 [==============================] - 1s 3ms/step
# 15/15 [==============================] - 0s 2ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.69
# Test RMSE: 2.14

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_10.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [93.78294372558594]   [94.45423889160156]
# 1     [93.78294372558594]   [94.45423889160156]
# 2     [93.78294372558594]   [94.45423889160156]
# 3     [93.78294372558594]   [94.45423889160156]
# 4     [93.78294372558594]   [94.45423889160156]
# ..                    ...                   ...
# 933   [189.2200164794922]  [190.05125427246094]
# 934  [195.32000732421875]  [196.13214111328125]
# 935  [195.91000366210938]  [196.71998596191406]
# 936  [183.88999938964844]  [184.73326110839844]
# 937               [111.0]  [111.72576904296875]
#
# [938 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [93.78294372558594]   [94.45423889160156]
# 1     [93.78294372558594]   [94.45423889160156]
# 2    [197.47999572753906]   [198.2838897705078]
# 3    [199.94000244140625]  [200.73353576660156]
# 4                 [174.0]  [174.85491943359375]
# ..                    ...                   ...
# 457   [64.73999786376953]    [65.3506088256836]
# 458    [75.4800033569336]   [76.10610961914062]
# 459   [70.19999694824219]    [70.8172378540039]
# 460   [47.11000061035156]   [47.72073745727539]
# 461                [39.0]  [39.624027252197266]
#
# [462 rows x 2 columns]

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Nasik_lstm_10.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 8s - loss: 0.0013 - 8s/epoch - 8ms/step
# Epoch 2/100
# 1039/1039 - 4s - loss: 6.6664e-05 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1039/1039 - 4s - loss: 5.8301e-05 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1039/1039 - 4s - loss: 4.1393e-05 - 4s/epoch - 4ms/step
# Epoch 5/100
# 1039/1039 - 4s - loss: 3.2086e-05 - 4s/epoch - 4ms/step
# Epoch 6/100
# 1039/1039 - 4s - loss: 3.3874e-05 - 4s/epoch - 4ms/step
# Epoch 7/100
# 1039/1039 - 5s - loss: 3.2125e-05 - 5s/epoch - 5ms/step
# Epoch 8/100
# 1039/1039 - 6s - loss: 2.9216e-05 - 6s/epoch - 5ms/step
# Epoch 9/100
# 1039/1039 - 5s - loss: 3.0280e-05 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1039/1039 - 4s - loss: 2.9638e-05 - 4s/epoch - 4ms/step
# Epoch 11/100
# 1039/1039 - 4s - loss: 3.1633e-05 - 4s/epoch - 4ms/step
# Epoch 12/100
# 1039/1039 - 4s - loss: 2.5465e-05 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1039/1039 - 4s - loss: 2.9479e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 1039/1039 - 4s - loss: 2.5684e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 1039/1039 - 4s - loss: 2.8391e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 1039/1039 - 4s - loss: 2.7455e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1039/1039 - 4s - loss: 2.2979e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 1039/1039 - 4s - loss: 2.2821e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 1039/1039 - 4s - loss: 2.0228e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 1039/1039 - 4s - loss: 2.8976e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 1039/1039 - 4s - loss: 2.2790e-05 - 4s/epoch - 4ms/step
# Epoch 22/100
# 1039/1039 - 4s - loss: 2.2754e-05 - 4s/epoch - 4ms/step
# Epoch 23/100
# 1039/1039 - 4s - loss: 2.1069e-05 - 4s/epoch - 4ms/step
# Epoch 24/100
# 1039/1039 - 4s - loss: 2.2189e-05 - 4s/epoch - 4ms/step
# Epoch 25/100
# 1039/1039 - 4s - loss: 2.6468e-05 - 4s/epoch - 4ms/step
# Epoch 26/100
# 1039/1039 - 4s - loss: 2.3970e-05 - 4s/epoch - 4ms/step
# Epoch 27/100
# 1039/1039 - 4s - loss: 2.8402e-05 - 4s/epoch - 4ms/step
# Epoch 28/100
# 1039/1039 - 4s - loss: 2.2980e-05 - 4s/epoch - 4ms/step
# Epoch 29/100
# 1039/1039 - 4s - loss: 2.1652e-05 - 4s/epoch - 4ms/step
# Epoch 30/100
# 1039/1039 - 4s - loss: 2.1220e-05 - 4s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 4s - loss: 2.7864e-05 - 4s/epoch - 4ms/step
# Epoch 32/100
# 1039/1039 - 4s - loss: 2.2735e-05 - 4s/epoch - 4ms/step
# Epoch 33/100
# 1039/1039 - 4s - loss: 2.3843e-05 - 4s/epoch - 4ms/step
# Epoch 34/100
# 1039/1039 - 4s - loss: 2.1690e-05 - 4s/epoch - 4ms/step
# Epoch 35/100
# 1039/1039 - 4s - loss: 2.4639e-05 - 4s/epoch - 4ms/step
# Epoch 36/100
# 1039/1039 - 4s - loss: 2.2618e-05 - 4s/epoch - 4ms/step
# Epoch 37/100
# 1039/1039 - 6s - loss: 2.0807e-05 - 6s/epoch - 6ms/step
# Epoch 38/100
# 1039/1039 - 4s - loss: 2.5981e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 4s - loss: 1.9209e-05 - 4s/epoch - 4ms/step
# Epoch 40/100
# 1039/1039 - 4s - loss: 2.2457e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 1039/1039 - 5s - loss: 2.8328e-05 - 5s/epoch - 4ms/step
# Epoch 42/100
# 1039/1039 - 4s - loss: 2.4696e-05 - 4s/epoch - 4ms/step
# Epoch 43/100
# 1039/1039 - 4s - loss: 2.2579e-05 - 4s/epoch - 4ms/step
# Epoch 44/100
# 1039/1039 - 5s - loss: 2.1124e-05 - 5s/epoch - 4ms/step
# Epoch 45/100
# 1039/1039 - 4s - loss: 2.4520e-05 - 4s/epoch - 4ms/step
# Epoch 46/100
# 1039/1039 - 5s - loss: 2.5445e-05 - 5s/epoch - 4ms/step
# Epoch 47/100
# 1039/1039 - 4s - loss: 2.3235e-05 - 4s/epoch - 4ms/step
# Epoch 48/100
# 1039/1039 - 4s - loss: 2.1129e-05 - 4s/epoch - 4ms/step
# Epoch 49/100
# 1039/1039 - 4s - loss: 2.3337e-05 - 4s/epoch - 4ms/step
# Epoch 50/100
# 1039/1039 - 4s - loss: 2.3940e-05 - 4s/epoch - 4ms/step
# Epoch 51/100
# 1039/1039 - 4s - loss: 2.3087e-05 - 4s/epoch - 4ms/step
# Epoch 52/100
# 1039/1039 - 4s - loss: 2.6839e-05 - 4s/epoch - 4ms/step
# Epoch 53/100
# 1039/1039 - 4s - loss: 2.2176e-05 - 4s/epoch - 4ms/step
# Epoch 54/100
# 1039/1039 - 4s - loss: 2.1340e-05 - 4s/epoch - 4ms/step
# Epoch 55/100
# 1039/1039 - 5s - loss: 2.1896e-05 - 5s/epoch - 5ms/step
# Epoch 56/100
# 1039/1039 - 6s - loss: 2.2199e-05 - 6s/epoch - 6ms/step
# Epoch 57/100
# 1039/1039 - 5s - loss: 2.3204e-05 - 5s/epoch - 5ms/step
# Epoch 58/100
# 1039/1039 - 4s - loss: 2.5031e-05 - 4s/epoch - 4ms/step
# Epoch 59/100
# 1039/1039 - 4s - loss: 1.9664e-05 - 4s/epoch - 4ms/step
# Epoch 60/100
# 1039/1039 - 4s - loss: 2.3857e-05 - 4s/epoch - 4ms/step
# Epoch 61/100
# 1039/1039 - 4s - loss: 2.3667e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 1039/1039 - 4s - loss: 2.2371e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 1039/1039 - 5s - loss: 2.3633e-05 - 5s/epoch - 5ms/step
# Epoch 64/100
# 1039/1039 - 5s - loss: 2.1131e-05 - 5s/epoch - 4ms/step
# Epoch 65/100
# 1039/1039 - 5s - loss: 2.1489e-05 - 5s/epoch - 5ms/step
# Epoch 66/100
# 1039/1039 - 5s - loss: 2.4137e-05 - 5s/epoch - 5ms/step
# Epoch 67/100
# 1039/1039 - 5s - loss: 1.9699e-05 - 5s/epoch - 4ms/step
# Epoch 68/100
# 1039/1039 - 4s - loss: 2.1839e-05 - 4s/epoch - 4ms/step
# Epoch 69/100
# 1039/1039 - 5s - loss: 2.0589e-05 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1039/1039 - 4s - loss: 1.8652e-05 - 4s/epoch - 4ms/step
# Epoch 71/100
# 1039/1039 - 5s - loss: 2.6728e-05 - 5s/epoch - 4ms/step
# Epoch 72/100
# 1039/1039 - 5s - loss: 2.1371e-05 - 5s/epoch - 5ms/step
# Epoch 73/100
# 1039/1039 - 5s - loss: 2.0498e-05 - 5s/epoch - 4ms/step
# Epoch 74/100
# 1039/1039 - 4s - loss: 2.3861e-05 - 4s/epoch - 4ms/step
# Epoch 75/100
# 1039/1039 - 4s - loss: 2.3121e-05 - 4s/epoch - 4ms/step
# Epoch 76/100
# 1039/1039 - 5s - loss: 1.9007e-05 - 5s/epoch - 5ms/step
# Epoch 77/100
# 1039/1039 - 5s - loss: 2.1281e-05 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1039/1039 - 5s - loss: 1.8726e-05 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1039/1039 - 4s - loss: 2.1141e-05 - 4s/epoch - 4ms/step
# Epoch 80/100
# 1039/1039 - 5s - loss: 2.6701e-05 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1039/1039 - 5s - loss: 2.4591e-05 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1039/1039 - 5s - loss: 2.0072e-05 - 5s/epoch - 4ms/step
# Epoch 83/100
# 1039/1039 - 4s - loss: 2.1597e-05 - 4s/epoch - 4ms/step
# Epoch 84/100
# 1039/1039 - 5s - loss: 2.0024e-05 - 5s/epoch - 4ms/step
# Epoch 85/100
# 1039/1039 - 5s - loss: 1.8525e-05 - 5s/epoch - 5ms/step
# Epoch 86/100
# 1039/1039 - 4s - loss: 2.6004e-05 - 4s/epoch - 4ms/step
# Epoch 87/100
# 1039/1039 - 4s - loss: 2.4261e-05 - 4s/epoch - 4ms/step
# Epoch 88/100
# 1039/1039 - 5s - loss: 2.0144e-05 - 5s/epoch - 5ms/step
# Epoch 89/100
# 1039/1039 - 4s - loss: 2.3090e-05 - 4s/epoch - 4ms/step
# Epoch 90/100
# 1039/1039 - 5s - loss: 2.1524e-05 - 5s/epoch - 5ms/step
# Epoch 91/100
# 1039/1039 - 5s - loss: 2.5934e-05 - 5s/epoch - 4ms/step
# Epoch 92/100
# 1039/1039 - 4s - loss: 1.9214e-05 - 4s/epoch - 4ms/step
# Epoch 93/100
# 1039/1039 - 4s - loss: 2.2372e-05 - 4s/epoch - 4ms/step
# Epoch 94/100
# 1039/1039 - 5s - loss: 2.2991e-05 - 5s/epoch - 4ms/step
# Epoch 95/100
# 1039/1039 - 5s - loss: 2.0285e-05 - 5s/epoch - 4ms/step
# Epoch 96/100
# 1039/1039 - 6s - loss: 2.0390e-05 - 6s/epoch - 6ms/step
# Epoch 97/100
# 1039/1039 - 5s - loss: 2.0460e-05 - 5s/epoch - 5ms/step
# Epoch 98/100
# 1039/1039 - 5s - loss: 1.9198e-05 - 5s/epoch - 4ms/step
# Epoch 99/100
# 1039/1039 - 4s - loss: 2.1039e-05 - 4s/epoch - 4ms/step
# Epoch 100/100
# 1039/1039 - 4s - loss: 2.5473e-05 - 4s/epoch - 4ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.28
# Test RMSE: 3.09

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_10.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0      [112.9000015258789]  [112.40971374511719]
# 1                 [115.25]  [114.73981475830078]
# 2      [102.4000015258789]   [101.9877700805664]
# 3                  [99.75]   [99.35494995117188]
# 4       [83.5199966430664]   [83.21320343017578]
# ...                    ...                   ...
# 1034  [110.01000213623047]  [109.54290008544922]
# 1035  [112.63999938964844]     [112.15185546875]
# 1036   [97.92999267578125]    [97.5462417602539]
# 1037   [97.94999694824219]   [97.56612396240234]
# 1038   [119.5199966430664]   [118.9710922241211]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [121.9800033569336]  [121.40721893310547]
# 1                 [67.75]   [67.51074981689453]
# 2     [91.37000274658203]    [91.0237808227539]
# 3      [88.0199966430664]   [87.69124603271484]
# 4     [95.61000061035156]   [95.24005889892578]
# ..                    ...                   ...
# 507   [73.86000061035156]   [73.59585571289062]
# 508   [81.33999633789062]    [81.0433120727539]
# 509   [96.59999084472656]   [96.22423553466797]
# 510  [52.630001068115234]  [52.451087951660156]
# 511   [41.70999526977539]  [41.578697204589844]
#
# [512 rows x 2 columns]

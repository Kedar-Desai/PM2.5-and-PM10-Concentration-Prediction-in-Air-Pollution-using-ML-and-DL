# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Nasik_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 6s - loss: 9.5196e-04 - 6s/epoch - 5ms/step
# Epoch 2/100
# 1039/1039 - 4s - loss: 9.5160e-05 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1039/1039 - 4s - loss: 2.3330e-05 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1039/1039 - 4s - loss: 8.7543e-05 - 4s/epoch - 4ms/step
# Epoch 5/100
# 1039/1039 - 4s - loss: 7.7205e-05 - 4s/epoch - 4ms/step
# Epoch 6/100
# 1039/1039 - 4s - loss: 5.6035e-05 - 4s/epoch - 4ms/step
# Epoch 7/100
# 1039/1039 - 4s - loss: 2.5845e-05 - 4s/epoch - 4ms/step
# Epoch 8/100
# 1039/1039 - 4s - loss: 2.4199e-05 - 4s/epoch - 4ms/step
# Epoch 9/100
# 1039/1039 - 5s - loss: 5.8079e-05 - 5s/epoch - 5ms/step
# Epoch 10/100
# 1039/1039 - 6s - loss: 2.0912e-05 - 6s/epoch - 5ms/step
# Epoch 11/100
# 1039/1039 - 5s - loss: 6.1349e-05 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1039/1039 - 4s - loss: 3.6144e-05 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1039/1039 - 4s - loss: 3.3074e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 1039/1039 - 4s - loss: 1.9743e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 1039/1039 - 4s - loss: 2.8043e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 1039/1039 - 4s - loss: 3.6134e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1039/1039 - 4s - loss: 3.6089e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 1039/1039 - 4s - loss: 3.9539e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 1039/1039 - 4s - loss: 1.9756e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 1039/1039 - 4s - loss: 7.4453e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 1039/1039 - 4s - loss: 1.4238e-05 - 4s/epoch - 4ms/step
# Epoch 22/100
# 1039/1039 - 4s - loss: 6.0608e-05 - 4s/epoch - 4ms/step
# Epoch 23/100
# 1039/1039 - 4s - loss: 4.0302e-05 - 4s/epoch - 4ms/step
# Epoch 24/100
# 1039/1039 - 4s - loss: 1.5967e-05 - 4s/epoch - 4ms/step
# Epoch 25/100
# 1039/1039 - 4s - loss: 1.4578e-05 - 4s/epoch - 4ms/step
# Epoch 26/100
# 1039/1039 - 4s - loss: 2.4040e-05 - 4s/epoch - 4ms/step
# Epoch 27/100
# 1039/1039 - 4s - loss: 2.6272e-05 - 4s/epoch - 4ms/step
# Epoch 28/100
# 1039/1039 - 4s - loss: 1.9199e-05 - 4s/epoch - 4ms/step
# Epoch 29/100
# 1039/1039 - 4s - loss: 4.1801e-05 - 4s/epoch - 4ms/step
# Epoch 30/100
# 1039/1039 - 4s - loss: 1.3849e-05 - 4s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 4s - loss: 5.1050e-05 - 4s/epoch - 4ms/step
# Epoch 32/100
# 1039/1039 - 4s - loss: 1.9839e-05 - 4s/epoch - 4ms/step
# Epoch 33/100
# 1039/1039 - 4s - loss: 2.3194e-05 - 4s/epoch - 4ms/step
# Epoch 34/100
# 1039/1039 - 5s - loss: 2.5871e-05 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1039/1039 - 4s - loss: 1.5213e-05 - 4s/epoch - 4ms/step
# Epoch 36/100
# 1039/1039 - 4s - loss: 1.4489e-05 - 4s/epoch - 4ms/step
# Epoch 37/100
# 1039/1039 - 4s - loss: 1.8458e-05 - 4s/epoch - 4ms/step
# Epoch 38/100
# 1039/1039 - 4s - loss: 3.0695e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 6s - loss: 2.2679e-05 - 6s/epoch - 6ms/step
# Epoch 40/100
# 1039/1039 - 4s - loss: 1.5111e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 1039/1039 - 4s - loss: 5.6760e-05 - 4s/epoch - 4ms/step
# Epoch 42/100
# 1039/1039 - 4s - loss: 4.0644e-05 - 4s/epoch - 4ms/step
# Epoch 43/100
# 1039/1039 - 5s - loss: 5.3243e-05 - 5s/epoch - 4ms/step
# Epoch 44/100
# 1039/1039 - 5s - loss: 4.2945e-05 - 5s/epoch - 4ms/step
# Epoch 45/100
# 1039/1039 - 4s - loss: 1.4462e-05 - 4s/epoch - 4ms/step
# Epoch 46/100
# 1039/1039 - 4s - loss: 2.7430e-05 - 4s/epoch - 4ms/step
# Epoch 47/100
# 1039/1039 - 4s - loss: 1.3563e-05 - 4s/epoch - 4ms/step
# Epoch 48/100
# 1039/1039 - 5s - loss: 2.2555e-05 - 5s/epoch - 4ms/step
# Epoch 49/100
# 1039/1039 - 4s - loss: 1.5565e-05 - 4s/epoch - 4ms/step
# Epoch 50/100
# 1039/1039 - 4s - loss: 3.3028e-05 - 4s/epoch - 4ms/step
# Epoch 51/100
# 1039/1039 - 4s - loss: 2.5061e-05 - 4s/epoch - 4ms/step
# Epoch 52/100
# 1039/1039 - 4s - loss: 2.4280e-05 - 4s/epoch - 4ms/step
# Epoch 53/100
# 1039/1039 - 4s - loss: 1.7902e-05 - 4s/epoch - 4ms/step
# Epoch 54/100
# 1039/1039 - 4s - loss: 3.4065e-05 - 4s/epoch - 4ms/step
# Epoch 55/100
# 1039/1039 - 4s - loss: 1.6175e-05 - 4s/epoch - 4ms/step
# Epoch 56/100
# 1039/1039 - 5s - loss: 2.2534e-05 - 5s/epoch - 4ms/step
# Epoch 57/100
# 1039/1039 - 6s - loss: 1.8692e-05 - 6s/epoch - 5ms/step
# Epoch 58/100
# 1039/1039 - 5s - loss: 2.4716e-05 - 5s/epoch - 5ms/step
# Epoch 59/100
# 1039/1039 - 5s - loss: 4.8271e-05 - 5s/epoch - 5ms/step
# Epoch 60/100
# 1039/1039 - 4s - loss: 1.0179e-05 - 4s/epoch - 4ms/step
# Epoch 61/100
# 1039/1039 - 4s - loss: 1.5704e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 1039/1039 - 4s - loss: 1.0954e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 1039/1039 - 4s - loss: 1.6523e-05 - 4s/epoch - 4ms/step
# Epoch 64/100
# 1039/1039 - 4s - loss: 2.7090e-05 - 4s/epoch - 4ms/step
# Epoch 65/100
# 1039/1039 - 5s - loss: 1.9676e-05 - 5s/epoch - 5ms/step
# Epoch 66/100
# 1039/1039 - 5s - loss: 2.6566e-05 - 5s/epoch - 4ms/step
# Epoch 67/100
# 1039/1039 - 5s - loss: 2.1267e-05 - 5s/epoch - 5ms/step
# Epoch 68/100
# 1039/1039 - 6s - loss: 2.3931e-05 - 6s/epoch - 5ms/step
# Epoch 69/100
# 1039/1039 - 5s - loss: 1.1570e-05 - 5s/epoch - 4ms/step
# Epoch 70/100
# 1039/1039 - 4s - loss: 2.2537e-05 - 4s/epoch - 4ms/step
# Epoch 71/100
# 1039/1039 - 5s - loss: 1.5716e-05 - 5s/epoch - 5ms/step
# Epoch 72/100
# 1039/1039 - 4s - loss: 1.7744e-05 - 4s/epoch - 4ms/step
# Epoch 73/100
# 1039/1039 - 5s - loss: 3.8510e-05 - 5s/epoch - 4ms/step
# Epoch 74/100
# 1039/1039 - 5s - loss: 9.5585e-06 - 5s/epoch - 4ms/step
# Epoch 75/100
# 1039/1039 - 5s - loss: 1.2123e-05 - 5s/epoch - 4ms/step
# Epoch 76/100
# 1039/1039 - 5s - loss: 1.0517e-05 - 5s/epoch - 4ms/step
# Epoch 77/100
# 1039/1039 - 4s - loss: 1.6016e-05 - 4s/epoch - 4ms/step
# Epoch 78/100
# 1039/1039 - 5s - loss: 3.6471e-05 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1039/1039 - 5s - loss: 2.0141e-05 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1039/1039 - 5s - loss: 3.6721e-05 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1039/1039 - 4s - loss: 2.4494e-05 - 4s/epoch - 4ms/step
# Epoch 82/100
# 1039/1039 - 5s - loss: 3.0736e-05 - 5s/epoch - 5ms/step
# Epoch 83/100
# 1039/1039 - 5s - loss: 1.0940e-05 - 5s/epoch - 4ms/step
# Epoch 84/100
# 1039/1039 - 4s - loss: 3.5479e-05 - 4s/epoch - 4ms/step
# Epoch 85/100
# 1039/1039 - 5s - loss: 1.4662e-05 - 5s/epoch - 4ms/step
# Epoch 86/100
# 1039/1039 - 4s - loss: 8.4029e-06 - 4s/epoch - 4ms/step
# Epoch 87/100
# 1039/1039 - 5s - loss: 1.1002e-05 - 5s/epoch - 5ms/step
# Epoch 88/100
# 1039/1039 - 4s - loss: 2.5623e-05 - 4s/epoch - 4ms/step
# Epoch 89/100
# 1039/1039 - 4s - loss: 2.8363e-05 - 4s/epoch - 4ms/step
# Epoch 90/100
# 1039/1039 - 5s - loss: 2.3619e-05 - 5s/epoch - 5ms/step
# Epoch 91/100
# 1039/1039 - 4s - loss: 2.1670e-05 - 4s/epoch - 4ms/step
# Epoch 92/100
# 1039/1039 - 5s - loss: 1.1360e-05 - 5s/epoch - 5ms/step
# Epoch 93/100
# 1039/1039 - 5s - loss: 2.2676e-05 - 5s/epoch - 4ms/step
# Epoch 94/100
# 1039/1039 - 4s - loss: 1.1668e-05 - 4s/epoch - 4ms/step
# Epoch 95/100
# 1039/1039 - 4s - loss: 2.6124e-05 - 4s/epoch - 4ms/step
# Epoch 96/100
# 1039/1039 - 4s - loss: 8.7754e-05 - 4s/epoch - 4ms/step
# Epoch 97/100
# 1039/1039 - 5s - loss: 9.1721e-06 - 5s/epoch - 5ms/step
# Epoch 98/100
# 1039/1039 - 6s - loss: 4.7929e-05 - 6s/epoch - 5ms/step
# Epoch 99/100
# 1039/1039 - 5s - loss: 1.2510e-05 - 5s/epoch - 5ms/step
# Epoch 100/100
# 1039/1039 - 5s - loss: 2.5968e-05 - 5s/epoch - 4ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 2.50
# Test RMSE: 1.55

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_2.5.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0      [69.81999969482422]    [67.9898681640625]
# 1      [56.97999954223633]    [56.0210075378418]
# 2                  [62.25]   [60.93171310424805]
# 3      [49.27000045776367]  [48.841529846191406]
# 4      [43.93000411987305]   [43.87269592285156]
# ...                    ...                   ...
# 1034   [62.91999816894531]  [61.556209564208984]
# 1035   [68.70999908447266]   [66.95462799072266]
# 1036  [55.709999084472656]   [54.83797836303711]
# 1037   [59.20000076293945]   [58.08934020996094]
# 1038   [77.94999694824219]    [75.5750961303711]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lastm_2.5_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0     [83.55999755859375]   [80.81175231933594]
# 1     [49.05000305175781]  [48.636756896972656]
# 2     [72.69999694824219]   [70.67633819580078]
# 3     [69.30000305175781]       [67.5048828125]
# 4     [64.43000030517578]   [62.96382141113281]
# ..                    ...                   ...
# 507  [33.209999084472656]  [33.907962799072266]
# 508   [43.45000457763672]   [43.42620849609375]
# 509  [46.119998931884766]   [45.91008377075195]
# 510  [31.670001983642578]    [32.4776611328125]
# 511  [28.610002517700195]  [29.636573791503906]
#
# [512 rows x 2 columns]

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Aurangabad_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 10s - loss: 0.0014 - 10s/epoch - 10ms/step
# Epoch 2/100
# 1039/1039 - 5s - loss: 5.4978e-04 - 5s/epoch - 5ms/step
# Epoch 3/100
# 1039/1039 - 5s - loss: 7.0363e-05 - 5s/epoch - 5ms/step
# Epoch 4/100
# 1039/1039 - 5s - loss: 6.3731e-05 - 5s/epoch - 5ms/step
# Epoch 5/100
# 1039/1039 - 5s - loss: 4.0369e-05 - 5s/epoch - 5ms/step
# Epoch 6/100
# 1039/1039 - 6s - loss: 2.4889e-05 - 6s/epoch - 6ms/step
# Epoch 7/100
# 1039/1039 - 5s - loss: 9.9650e-05 - 5s/epoch - 5ms/step
# Epoch 8/100
# 1039/1039 - 5s - loss: 2.7155e-05 - 5s/epoch - 5ms/step
# Epoch 9/100
# 1039/1039 - 5s - loss: 3.5945e-05 - 5s/epoch - 5ms/step
# Epoch 10/100
# 1039/1039 - 5s - loss: 4.9020e-05 - 5s/epoch - 5ms/step
# Epoch 11/100
# 1039/1039 - 5s - loss: 3.7098e-05 - 5s/epoch - 5ms/step
# Epoch 12/100
# 1039/1039 - 5s - loss: 2.9835e-05 - 5s/epoch - 5ms/step
# Epoch 13/100
# 1039/1039 - 5s - loss: 2.0805e-05 - 5s/epoch - 5ms/step
# Epoch 14/100
# 1039/1039 - 5s - loss: 4.4160e-05 - 5s/epoch - 5ms/step
# Epoch 15/100
# 1039/1039 - 5s - loss: 3.5693e-05 - 5s/epoch - 5ms/step
# Epoch 16/100
# 1039/1039 - 5s - loss: 5.4844e-05 - 5s/epoch - 5ms/step
# Epoch 17/100
# 1039/1039 - 5s - loss: 2.0981e-05 - 5s/epoch - 5ms/step
# Epoch 18/100
# 1039/1039 - 6s - loss: 2.7689e-05 - 6s/epoch - 5ms/step
# Epoch 19/100
# 1039/1039 - 5s - loss: 5.9216e-05 - 5s/epoch - 5ms/step
# Epoch 20/100
# 1039/1039 - 5s - loss: 4.3055e-05 - 5s/epoch - 5ms/step
# Epoch 21/100
# 1039/1039 - 5s - loss: 4.4248e-05 - 5s/epoch - 5ms/step
# Epoch 22/100
# 1039/1039 - 5s - loss: 1.5725e-05 - 5s/epoch - 5ms/step
# Epoch 23/100
# 1039/1039 - 5s - loss: 1.7943e-05 - 5s/epoch - 5ms/step
# Epoch 24/100
# 1039/1039 - 5s - loss: 2.6732e-05 - 5s/epoch - 5ms/step
# Epoch 25/100
# 1039/1039 - 5s - loss: 3.4147e-05 - 5s/epoch - 5ms/step
# Epoch 26/100
# 1039/1039 - 5s - loss: 3.3910e-05 - 5s/epoch - 5ms/step
# Epoch 27/100
# 1039/1039 - 5s - loss: 1.8016e-05 - 5s/epoch - 5ms/step
# Epoch 28/100
# 1039/1039 - 5s - loss: 3.2420e-05 - 5s/epoch - 5ms/step
# Epoch 29/100
# 1039/1039 - 5s - loss: 3.6880e-05 - 5s/epoch - 5ms/step
# Epoch 30/100
# 1039/1039 - 5s - loss: 2.4705e-05 - 5s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 5s - loss: 4.4194e-05 - 5s/epoch - 5ms/step
# Epoch 32/100
# 1039/1039 - 5s - loss: 5.2122e-05 - 5s/epoch - 5ms/step
# Epoch 33/100
# 1039/1039 - 5s - loss: 2.5195e-05 - 5s/epoch - 4ms/step
# Epoch 34/100
# 1039/1039 - 5s - loss: 3.1231e-05 - 5s/epoch - 5ms/step
# Epoch 35/100
# 1039/1039 - 5s - loss: 4.7796e-05 - 5s/epoch - 5ms/step
# Epoch 36/100
# 1039/1039 - 5s - loss: 1.6564e-05 - 5s/epoch - 5ms/step
# Epoch 37/100
# 1039/1039 - 5s - loss: 3.2920e-05 - 5s/epoch - 5ms/step
# Epoch 38/100
# 1039/1039 - 5s - loss: 1.5979e-05 - 5s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 5s - loss: 2.0068e-05 - 5s/epoch - 5ms/step
# Epoch 40/100
# 1039/1039 - 5s - loss: 3.5415e-05 - 5s/epoch - 5ms/step
# Epoch 41/100
# 1039/1039 - 5s - loss: 1.0310e-04 - 5s/epoch - 4ms/step
# Epoch 42/100
# 1039/1039 - 5s - loss: 1.9106e-05 - 5s/epoch - 5ms/step
# Epoch 43/100
# 1039/1039 - 5s - loss: 4.8293e-05 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1039/1039 - 5s - loss: 3.3398e-05 - 5s/epoch - 5ms/step
# Epoch 45/100
# 1039/1039 - 5s - loss: 2.0897e-05 - 5s/epoch - 5ms/step
# Epoch 46/100
# 1039/1039 - 5s - loss: 4.5107e-05 - 5s/epoch - 5ms/step
# Epoch 47/100
# 1039/1039 - 5s - loss: 3.5957e-05 - 5s/epoch - 5ms/step
# Epoch 48/100
# 1039/1039 - 5s - loss: 2.3685e-05 - 5s/epoch - 4ms/step
# Epoch 49/100
# 1039/1039 - 5s - loss: 3.0927e-05 - 5s/epoch - 5ms/step
# Epoch 50/100
# 1039/1039 - 5s - loss: 1.6405e-05 - 5s/epoch - 5ms/step
# Epoch 51/100
# 1039/1039 - 5s - loss: 4.1761e-05 - 5s/epoch - 5ms/step
# Epoch 52/100
# 1039/1039 - 5s - loss: 5.5261e-05 - 5s/epoch - 5ms/step
# Epoch 53/100
# 1039/1039 - 5s - loss: 2.9410e-05 - 5s/epoch - 5ms/step
# Epoch 54/100
# 1039/1039 - 6s - loss: 2.0715e-05 - 6s/epoch - 5ms/step
# Epoch 55/100
# 1039/1039 - 5s - loss: 3.4793e-05 - 5s/epoch - 5ms/step
# Epoch 56/100
# 1039/1039 - 6s - loss: 2.3186e-05 - 6s/epoch - 6ms/step
# Epoch 57/100
# 1039/1039 - 5s - loss: 3.0011e-05 - 5s/epoch - 5ms/step
# Epoch 58/100
# 1039/1039 - 5s - loss: 2.5609e-05 - 5s/epoch - 5ms/step
# Epoch 59/100
# 1039/1039 - 5s - loss: 2.4866e-05 - 5s/epoch - 5ms/step
# Epoch 60/100
# 1039/1039 - 5s - loss: 3.6452e-05 - 5s/epoch - 5ms/step
# Epoch 61/100
# 1039/1039 - 5s - loss: 3.9427e-05 - 5s/epoch - 5ms/step
# Epoch 62/100
# 1039/1039 - 5s - loss: 4.3310e-05 - 5s/epoch - 5ms/step
# Epoch 63/100
# 1039/1039 - 5s - loss: 2.8704e-05 - 5s/epoch - 5ms/step
# Epoch 64/100
# 1039/1039 - 5s - loss: 2.0290e-05 - 5s/epoch - 5ms/step
# Epoch 65/100
# 1039/1039 - 5s - loss: 1.6816e-05 - 5s/epoch - 5ms/step
# Epoch 66/100
# 1039/1039 - 5s - loss: 2.9661e-05 - 5s/epoch - 5ms/step
# Epoch 67/100
# 1039/1039 - 5s - loss: 2.1992e-05 - 5s/epoch - 5ms/step
# Epoch 68/100
# 1039/1039 - 5s - loss: 3.3277e-05 - 5s/epoch - 5ms/step
# Epoch 69/100
# 1039/1039 - 5s - loss: 3.0754e-05 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1039/1039 - 5s - loss: 2.5730e-05 - 5s/epoch - 5ms/step
# Epoch 71/100
# 1039/1039 - 5s - loss: 5.4003e-05 - 5s/epoch - 5ms/step
# Epoch 72/100
# 1039/1039 - 5s - loss: 1.4575e-05 - 5s/epoch - 5ms/step
# Epoch 73/100
# 1039/1039 - 5s - loss: 5.5059e-05 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1039/1039 - 5s - loss: 1.4674e-05 - 5s/epoch - 5ms/step
# Epoch 75/100
# 1039/1039 - 5s - loss: 4.4616e-05 - 5s/epoch - 5ms/step
# Epoch 76/100
# 1039/1039 - 5s - loss: 1.3057e-05 - 5s/epoch - 5ms/step
# Epoch 77/100
# 1039/1039 - 5s - loss: 2.3983e-05 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1039/1039 - 5s - loss: 1.2335e-05 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1039/1039 - 5s - loss: 2.1124e-05 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1039/1039 - 5s - loss: 3.3125e-05 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1039/1039 - 5s - loss: 1.3458e-05 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1039/1039 - 5s - loss: 2.2230e-05 - 5s/epoch - 5ms/step
# Epoch 83/100
# 1039/1039 - 5s - loss: 6.0972e-05 - 5s/epoch - 5ms/step
# Epoch 84/100
# 1039/1039 - 5s - loss: 2.1876e-05 - 5s/epoch - 5ms/step
# Epoch 85/100
# 1039/1039 - 5s - loss: 4.1738e-05 - 5s/epoch - 5ms/step
# Epoch 86/100
# 1039/1039 - 5s - loss: 2.8140e-05 - 5s/epoch - 5ms/step
# Epoch 87/100
# 1039/1039 - 5s - loss: 4.8864e-05 - 5s/epoch - 5ms/step
# Epoch 88/100
# 1039/1039 - 5s - loss: 1.5092e-05 - 5s/epoch - 5ms/step
# Epoch 89/100
# 1039/1039 - 5s - loss: 3.3154e-05 - 5s/epoch - 5ms/step
# Epoch 90/100
# 1039/1039 - 5s - loss: 1.2382e-05 - 5s/epoch - 5ms/step
# Epoch 91/100
# 1039/1039 - 5s - loss: 2.3119e-05 - 5s/epoch - 5ms/step
# Epoch 92/100
# 1039/1039 - 5s - loss: 5.5514e-05 - 5s/epoch - 5ms/step
# Epoch 93/100
# 1039/1039 - 5s - loss: 7.1812e-05 - 5s/epoch - 5ms/step
# Epoch 94/100
# 1039/1039 - 5s - loss: 5.3436e-05 - 5s/epoch - 5ms/step
# Epoch 95/100
# 1039/1039 - 5s - loss: 4.7825e-05 - 5s/epoch - 5ms/step
# Epoch 96/100
# 1039/1039 - 5s - loss: 2.2338e-05 - 5s/epoch - 5ms/step
# Epoch 97/100
# 1039/1039 - 5s - loss: 1.3086e-05 - 5s/epoch - 5ms/step
# Epoch 98/100
# 1039/1039 - 5s - loss: 1.1097e-04 - 5s/epoch - 5ms/step
# Epoch 99/100
# 1039/1039 - 5s - loss: 2.0876e-05 - 5s/epoch - 5ms/step
# Epoch 100/100
# 1039/1039 - 5s - loss: 1.8256e-05 - 5s/epoch - 5ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 4ms/step
# 16/16 [==============================] - 0s 4ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.42
# Test RMSE: 0.43

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lastm_10.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0     [37.099998474121094]  [36.675350189208984]
# 1      [67.44999694824219]   [66.95222473144531]
# 2     [30.560001373291016]   [30.18744468688965]
# 3      [45.86000061035156]   [45.38711166381836]
# 4      [36.93000030517578]  [36.506526947021484]
# ...                    ...                   ...
# 1034  [38.301639556884766]   [37.86894226074219]
# 1035  [38.301639556884766]   [37.86894226074219]
# 1036  [38.301639556884766]   [37.86894226074219]
# 1037  [38.301639556884766]   [37.86894226074219]
# 1038  [38.301639556884766]   [37.86894226074219]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lastm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0    [38.301639556884766]   [37.86894226074219]
# 1    [38.301639556884766]   [37.86894226074219]
# 2    [38.301639556884766]   [37.86894226074219]
# 3    [38.301639556884766]   [37.86894226074219]
# 4    [38.301639556884766]   [37.86894226074219]
# ..                    ...                   ...
# 507   [38.36000061035156]   [37.92692565917969]
# 508   [46.47999954223633]   [46.00458908081055]
# 509   [62.20000076293945]  [61.696983337402344]
# 510    [38.9900016784668]   [38.55290985107422]
# 511  [47.720001220703125]   [47.23988342285156]
#
# [512 rows x 2 columns]

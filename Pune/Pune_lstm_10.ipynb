# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Pune_lstm_10.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 8s - loss: 0.0011 - 8s/epoch - 8ms/step
# Epoch 2/100
# 1039/1039 - 4s - loss: 6.0088e-05 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1039/1039 - 4s - loss: 4.1370e-05 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1039/1039 - 4s - loss: 3.6616e-05 - 4s/epoch - 4ms/step
# Epoch 5/100
# 1039/1039 - 4s - loss: 3.7871e-05 - 4s/epoch - 4ms/step
# Epoch 6/100
# 1039/1039 - 4s - loss: 3.4040e-05 - 4s/epoch - 4ms/step
# Epoch 7/100
# 1039/1039 - 4s - loss: 3.8321e-05 - 4s/epoch - 4ms/step
# Epoch 8/100
# 1039/1039 - 4s - loss: 3.1898e-05 - 4s/epoch - 4ms/step
# Epoch 9/100
# 1039/1039 - 4s - loss: 3.0049e-05 - 4s/epoch - 4ms/step
# Epoch 10/100
# 1039/1039 - 4s - loss: 3.0507e-05 - 4s/epoch - 4ms/step
# Epoch 11/100
# 1039/1039 - 4s - loss: 2.6598e-05 - 4s/epoch - 4ms/step
# Epoch 12/100
# 1039/1039 - 4s - loss: 3.1353e-05 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1039/1039 - 4s - loss: 2.9070e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 1039/1039 - 4s - loss: 2.9824e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 1039/1039 - 4s - loss: 2.9512e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 1039/1039 - 4s - loss: 2.8156e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1039/1039 - 4s - loss: 2.8259e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 1039/1039 - 4s - loss: 2.2117e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 1039/1039 - 4s - loss: 2.5197e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 1039/1039 - 4s - loss: 2.8624e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 1039/1039 - 4s - loss: 2.7042e-05 - 4s/epoch - 4ms/step
# Epoch 22/100
# 1039/1039 - 4s - loss: 2.8149e-05 - 4s/epoch - 4ms/step
# Epoch 23/100
# 1039/1039 - 4s - loss: 2.5386e-05 - 4s/epoch - 4ms/step
# Epoch 24/100
# 1039/1039 - 4s - loss: 2.2451e-05 - 4s/epoch - 4ms/step
# Epoch 25/100
# 1039/1039 - 4s - loss: 2.4881e-05 - 4s/epoch - 4ms/step
# Epoch 26/100
# 1039/1039 - 4s - loss: 2.6215e-05 - 4s/epoch - 4ms/step
# Epoch 27/100
# 1039/1039 - 4s - loss: 2.5156e-05 - 4s/epoch - 4ms/step
# Epoch 28/100
# 1039/1039 - 4s - loss: 2.2240e-05 - 4s/epoch - 4ms/step
# Epoch 29/100
# 1039/1039 - 4s - loss: 2.6540e-05 - 4s/epoch - 4ms/step
# Epoch 30/100
# 1039/1039 - 4s - loss: 2.2937e-05 - 4s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 4s - loss: 2.7526e-05 - 4s/epoch - 4ms/step
# Epoch 32/100
# 1039/1039 - 4s - loss: 2.6162e-05 - 4s/epoch - 4ms/step
# Epoch 33/100
# 1039/1039 - 4s - loss: 2.3638e-05 - 4s/epoch - 3ms/step
# Epoch 34/100
# 1039/1039 - 4s - loss: 2.3229e-05 - 4s/epoch - 4ms/step
# Epoch 35/100
# 1039/1039 - 4s - loss: 2.6790e-05 - 4s/epoch - 4ms/step
# Epoch 36/100
# 1039/1039 - 4s - loss: 2.8870e-05 - 4s/epoch - 4ms/step
# Epoch 37/100
# 1039/1039 - 4s - loss: 2.7539e-05 - 4s/epoch - 4ms/step
# Epoch 38/100
# 1039/1039 - 4s - loss: 2.6036e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 4s - loss: 2.4772e-05 - 4s/epoch - 4ms/step
# Epoch 40/100
# 1039/1039 - 4s - loss: 2.3357e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 1039/1039 - 4s - loss: 2.3450e-05 - 4s/epoch - 4ms/step
# Epoch 42/100
# 1039/1039 - 4s - loss: 2.8599e-05 - 4s/epoch - 4ms/step
# Epoch 43/100
# 1039/1039 - 4s - loss: 2.1041e-05 - 4s/epoch - 4ms/step
# Epoch 44/100
# 1039/1039 - 4s - loss: 2.4628e-05 - 4s/epoch - 4ms/step
# Epoch 45/100
# 1039/1039 - 4s - loss: 3.0558e-05 - 4s/epoch - 4ms/step
# Epoch 46/100
# 1039/1039 - 4s - loss: 2.3087e-05 - 4s/epoch - 4ms/step
# Epoch 47/100
# 1039/1039 - 4s - loss: 2.6907e-05 - 4s/epoch - 4ms/step
# Epoch 48/100
# 1039/1039 - 4s - loss: 2.1449e-05 - 4s/epoch - 4ms/step
# Epoch 49/100
# 1039/1039 - 4s - loss: 2.2231e-05 - 4s/epoch - 4ms/step
# Epoch 50/100
# 1039/1039 - 4s - loss: 2.3509e-05 - 4s/epoch - 4ms/step
# Epoch 51/100
# 1039/1039 - 4s - loss: 2.4944e-05 - 4s/epoch - 4ms/step
# Epoch 52/100
# 1039/1039 - 4s - loss: 2.5067e-05 - 4s/epoch - 4ms/step
# Epoch 53/100
# 1039/1039 - 4s - loss: 2.6734e-05 - 4s/epoch - 4ms/step
# Epoch 54/100
# 1039/1039 - 4s - loss: 2.4854e-05 - 4s/epoch - 4ms/step
# Epoch 55/100
# 1039/1039 - 4s - loss: 2.5852e-05 - 4s/epoch - 4ms/step
# Epoch 56/100
# 1039/1039 - 4s - loss: 2.1414e-05 - 4s/epoch - 4ms/step
# Epoch 57/100
# 1039/1039 - 4s - loss: 2.1950e-05 - 4s/epoch - 4ms/step
# Epoch 58/100
# 1039/1039 - 4s - loss: 2.8125e-05 - 4s/epoch - 4ms/step
# Epoch 59/100
# 1039/1039 - 4s - loss: 1.9429e-05 - 4s/epoch - 4ms/step
# Epoch 60/100
# 1039/1039 - 4s - loss: 2.5407e-05 - 4s/epoch - 4ms/step
# Epoch 61/100
# 1039/1039 - 4s - loss: 2.0732e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 1039/1039 - 4s - loss: 2.7424e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 1039/1039 - 4s - loss: 2.3443e-05 - 4s/epoch - 4ms/step
# Epoch 64/100
# 1039/1039 - 4s - loss: 2.0981e-05 - 4s/epoch - 4ms/step
# Epoch 65/100
# 1039/1039 - 4s - loss: 2.8236e-05 - 4s/epoch - 4ms/step
# Epoch 66/100
# 1039/1039 - 4s - loss: 2.8337e-05 - 4s/epoch - 4ms/step
# Epoch 67/100
# 1039/1039 - 4s - loss: 2.8551e-05 - 4s/epoch - 4ms/step
# Epoch 68/100
# 1039/1039 - 4s - loss: 2.2044e-05 - 4s/epoch - 4ms/step
# Epoch 69/100
# 1039/1039 - 4s - loss: 2.3327e-05 - 4s/epoch - 4ms/step
# Epoch 70/100
# 1039/1039 - 4s - loss: 2.2771e-05 - 4s/epoch - 4ms/step
# Epoch 71/100
# 1039/1039 - 4s - loss: 2.4622e-05 - 4s/epoch - 4ms/step
# Epoch 72/100
# 1039/1039 - 4s - loss: 1.8362e-05 - 4s/epoch - 4ms/step
# Epoch 73/100
# 1039/1039 - 4s - loss: 2.7198e-05 - 4s/epoch - 4ms/step
# Epoch 74/100
# 1039/1039 - 4s - loss: 2.4331e-05 - 4s/epoch - 4ms/step
# Epoch 75/100
# 1039/1039 - 4s - loss: 2.5975e-05 - 4s/epoch - 4ms/step
# Epoch 76/100
# 1039/1039 - 4s - loss: 2.2505e-05 - 4s/epoch - 4ms/step
# Epoch 77/100
# 1039/1039 - 4s - loss: 2.1413e-05 - 4s/epoch - 4ms/step
# Epoch 78/100
# 1039/1039 - 4s - loss: 2.2704e-05 - 4s/epoch - 4ms/step
# Epoch 79/100
# 1039/1039 - 4s - loss: 2.6508e-05 - 4s/epoch - 4ms/step
# Epoch 80/100
# 1039/1039 - 4s - loss: 2.3735e-05 - 4s/epoch - 4ms/step
# Epoch 81/100
# 1039/1039 - 4s - loss: 1.8421e-05 - 4s/epoch - 4ms/step
# Epoch 82/100
# 1039/1039 - 4s - loss: 2.4256e-05 - 4s/epoch - 4ms/step
# Epoch 83/100
# 1039/1039 - 4s - loss: 2.3561e-05 - 4s/epoch - 4ms/step
# Epoch 84/100
# 1039/1039 - 4s - loss: 2.2436e-05 - 4s/epoch - 4ms/step
# Epoch 85/100
# 1039/1039 - 4s - loss: 2.5101e-05 - 4s/epoch - 4ms/step
# Epoch 86/100
# 1039/1039 - 4s - loss: 2.2701e-05 - 4s/epoch - 4ms/step
# Epoch 87/100
# 1039/1039 - 4s - loss: 2.2641e-05 - 4s/epoch - 4ms/step
# Epoch 88/100
# 1039/1039 - 4s - loss: 2.2807e-05 - 4s/epoch - 4ms/step
# Epoch 89/100
# 1039/1039 - 4s - loss: 2.1303e-05 - 4s/epoch - 4ms/step
# Epoch 90/100
# 1039/1039 - 4s - loss: 2.2304e-05 - 4s/epoch - 4ms/step
# Epoch 91/100
# 1039/1039 - 4s - loss: 2.4579e-05 - 4s/epoch - 4ms/step
# Epoch 92/100
# 1039/1039 - 4s - loss: 2.5115e-05 - 4s/epoch - 4ms/step
# Epoch 93/100
# 1039/1039 - 5s - loss: 2.2680e-05 - 5s/epoch - 4ms/step
# Epoch 94/100
# 1039/1039 - 4s - loss: 2.4504e-05 - 4s/epoch - 4ms/step
# Epoch 95/100
# 1039/1039 - 4s - loss: 2.1831e-05 - 4s/epoch - 4ms/step
# Epoch 96/100
# 1039/1039 - 4s - loss: 2.1242e-05 - 4s/epoch - 4ms/step
# Epoch 97/100
# 1039/1039 - 5s - loss: 2.0969e-05 - 5s/epoch - 4ms/step
# Epoch 98/100
# 1039/1039 - 4s - loss: 2.4340e-05 - 4s/epoch - 4ms/step
# Epoch 99/100
# 1039/1039 - 4s - loss: 2.1623e-05 - 4s/epoch - 4ms/step
# Epoch 100/100
# 1039/1039 - 4s - loss: 2.4685e-05 - 4s/epoch - 4ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.98
# Test RMSE: 4.17

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_10.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0     [203.30001831054688]  [204.83567810058594]
# 1     [170.37001037597656]   [172.0649871826172]
# 2     [153.04000854492188]   [154.7190704345703]
# 3      [151.9499969482422]   [153.6260986328125]
# 4      [159.3200225830078]  [161.01187133789062]
# ...                    ...                   ...
# 1034   [109.6100082397461]  [111.02509307861328]
# 1035   [81.56999969482422]   [82.70194244384766]
# 1036    [82.5999984741211]   [83.74327087402344]
# 1037    [67.2699966430664]    [68.2405014038086]
# 1038   [59.29999542236328]    [60.1784553527832]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0    [51.529998779296875]  [52.318519592285156]
# 1    [46.880001068115234]     [47.614990234375]
# 2     [64.08999633789062]   [65.02386474609375]
# 3     [86.08999633789062]     [87.271240234375]
# 4    [108.29000854492188]   [109.6932144165039]
# ..                    ...                   ...
# 507   [48.45000076293945]  [49.203025817871094]
# 508   [52.09000015258789]  [52.884986877441406]
# 509   [50.58000564575195]   [51.35755920410156]
# 510                [43.0]   [43.69066619873047]
# 511   [45.65999984741211]  [46.381011962890625]
#
# [512 rows x 2 columns]

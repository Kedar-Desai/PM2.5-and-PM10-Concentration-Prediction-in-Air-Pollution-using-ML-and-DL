# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Pune_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(60, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 6s - loss: 9.1122e-04 - 6s/epoch - 5ms/step
# Epoch 2/100
# 1039/1039 - 3s - loss: 6.0787e-05 - 3s/epoch - 3ms/step
# Epoch 3/100
# 1039/1039 - 3s - loss: 2.7312e-05 - 3s/epoch - 3ms/step
# Epoch 4/100
# 1039/1039 - 3s - loss: 3.3328e-05 - 3s/epoch - 3ms/step
# Epoch 5/100
# 1039/1039 - 3s - loss: 4.4377e-05 - 3s/epoch - 3ms/step
# Epoch 6/100
# 1039/1039 - 3s - loss: 3.7729e-05 - 3s/epoch - 3ms/step
# Epoch 7/100
# 1039/1039 - 3s - loss: 1.8186e-05 - 3s/epoch - 3ms/step
# Epoch 8/100
# 1039/1039 - 3s - loss: 2.4480e-05 - 3s/epoch - 3ms/step
# Epoch 9/100
# 1039/1039 - 3s - loss: 1.9454e-05 - 3s/epoch - 3ms/step
# Epoch 10/100
# 1039/1039 - 3s - loss: 3.8728e-05 - 3s/epoch - 3ms/step
# Epoch 11/100
# 1039/1039 - 3s - loss: 3.1329e-05 - 3s/epoch - 3ms/step
# Epoch 12/100
# 1039/1039 - 3s - loss: 2.0654e-05 - 3s/epoch - 3ms/step
# Epoch 13/100
# 1039/1039 - 3s - loss: 4.0600e-05 - 3s/epoch - 3ms/step
# Epoch 14/100
# 1039/1039 - 3s - loss: 1.8023e-05 - 3s/epoch - 3ms/step
# Epoch 15/100
# 1039/1039 - 3s - loss: 2.5231e-05 - 3s/epoch - 3ms/step
# Epoch 16/100
# 1039/1039 - 3s - loss: 2.3917e-05 - 3s/epoch - 3ms/step
# Epoch 17/100
# 1039/1039 - 3s - loss: 2.0199e-05 - 3s/epoch - 3ms/step
# Epoch 18/100
# 1039/1039 - 3s - loss: 3.7236e-05 - 3s/epoch - 3ms/step
# Epoch 19/100
# 1039/1039 - 3s - loss: 3.7892e-05 - 3s/epoch - 3ms/step
# Epoch 20/100
# 1039/1039 - 3s - loss: 3.1934e-05 - 3s/epoch - 3ms/step
# Epoch 21/100
# 1039/1039 - 3s - loss: 1.8281e-05 - 3s/epoch - 3ms/step
# Epoch 22/100
# 1039/1039 - 3s - loss: 3.1907e-05 - 3s/epoch - 3ms/step
# Epoch 23/100
# 1039/1039 - 3s - loss: 3.2277e-05 - 3s/epoch - 3ms/step
# Epoch 24/100
# 1039/1039 - 3s - loss: 1.7777e-05 - 3s/epoch - 3ms/step
# Epoch 25/100
# 1039/1039 - 3s - loss: 1.7606e-05 - 3s/epoch - 3ms/step
# Epoch 26/100
# 1039/1039 - 3s - loss: 3.4251e-05 - 3s/epoch - 3ms/step
# Epoch 27/100
# 1039/1039 - 3s - loss: 2.5011e-05 - 3s/epoch - 3ms/step
# Epoch 28/100
# 1039/1039 - 3s - loss: 1.3185e-05 - 3s/epoch - 3ms/step
# Epoch 29/100
# 1039/1039 - 3s - loss: 2.1308e-05 - 3s/epoch - 3ms/step
# Epoch 30/100
# 1039/1039 - 4s - loss: 5.6021e-05 - 4s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 4s - loss: 4.8452e-05 - 4s/epoch - 3ms/step
# Epoch 32/100
# 1039/1039 - 3s - loss: 2.0727e-05 - 3s/epoch - 3ms/step
# Epoch 33/100
# 1039/1039 - 3s - loss: 2.8340e-05 - 3s/epoch - 3ms/step
# Epoch 34/100
# 1039/1039 - 3s - loss: 3.5756e-05 - 3s/epoch - 3ms/step
# Epoch 35/100
# 1039/1039 - 3s - loss: 1.7833e-05 - 3s/epoch - 3ms/step
# Epoch 36/100
# 1039/1039 - 3s - loss: 1.8423e-05 - 3s/epoch - 3ms/step
# Epoch 37/100
# 1039/1039 - 4s - loss: 3.1659e-05 - 4s/epoch - 4ms/step
# Epoch 38/100
# 1039/1039 - 4s - loss: 2.9019e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 3s - loss: 3.5517e-05 - 3s/epoch - 3ms/step
# Epoch 40/100
# 1039/1039 - 4s - loss: 2.5682e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 1039/1039 - 4s - loss: 1.5312e-05 - 4s/epoch - 3ms/step
# Epoch 42/100
# 1039/1039 - 3s - loss: 3.2884e-05 - 3s/epoch - 3ms/step
# Epoch 43/100
# 1039/1039 - 3s - loss: 3.6097e-05 - 3s/epoch - 3ms/step
# Epoch 44/100
# 1039/1039 - 3s - loss: 1.3004e-05 - 3s/epoch - 3ms/step
# Epoch 45/100
# 1039/1039 - 4s - loss: 1.0555e-05 - 4s/epoch - 3ms/step
# Epoch 46/100
# 1039/1039 - 3s - loss: 2.1646e-05 - 3s/epoch - 3ms/step
# Epoch 47/100
# 1039/1039 - 3s - loss: 4.9911e-05 - 3s/epoch - 3ms/step
# Epoch 48/100
# 1039/1039 - 3s - loss: 1.9393e-05 - 3s/epoch - 3ms/step
# Epoch 49/100
# 1039/1039 - 3s - loss: 6.3880e-05 - 3s/epoch - 3ms/step
# Epoch 50/100
# 1039/1039 - 3s - loss: 1.8974e-05 - 3s/epoch - 3ms/step
# Epoch 51/100
# 1039/1039 - 3s - loss: 2.5589e-05 - 3s/epoch - 3ms/step
# Epoch 52/100
# 1039/1039 - 3s - loss: 3.9958e-05 - 3s/epoch - 3ms/step
# Epoch 53/100
# 1039/1039 - 3s - loss: 2.0313e-05 - 3s/epoch - 3ms/step
# Epoch 54/100
# 1039/1039 - 3s - loss: 1.6560e-05 - 3s/epoch - 3ms/step
# Epoch 55/100
# 1039/1039 - 3s - loss: 2.6369e-05 - 3s/epoch - 3ms/step
# Epoch 56/100
# 1039/1039 - 3s - loss: 4.1700e-05 - 3s/epoch - 3ms/step
# Epoch 57/100
# 1039/1039 - 3s - loss: 2.4164e-05 - 3s/epoch - 3ms/step
# Epoch 58/100
# 1039/1039 - 3s - loss: 4.5348e-05 - 3s/epoch - 3ms/step
# Epoch 59/100
# 1039/1039 - 3s - loss: 2.3303e-05 - 3s/epoch - 3ms/step
# Epoch 60/100
# 1039/1039 - 3s - loss: 2.1563e-05 - 3s/epoch - 3ms/step
# Epoch 61/100
# 1039/1039 - 3s - loss: 1.2096e-05 - 3s/epoch - 3ms/step
# Epoch 62/100
# 1039/1039 - 3s - loss: 1.2926e-05 - 3s/epoch - 3ms/step
# Epoch 63/100
# 1039/1039 - 3s - loss: 1.3522e-05 - 3s/epoch - 3ms/step
# Epoch 64/100
# 1039/1039 - 3s - loss: 2.7921e-05 - 3s/epoch - 3ms/step
# Epoch 65/100
# 1039/1039 - 3s - loss: 3.7259e-05 - 3s/epoch - 3ms/step
# Epoch 66/100
# 1039/1039 - 3s - loss: 1.7915e-05 - 3s/epoch - 3ms/step
# Epoch 67/100
# 1039/1039 - 3s - loss: 3.0370e-05 - 3s/epoch - 3ms/step
# Epoch 68/100
# 1039/1039 - 3s - loss: 1.3689e-05 - 3s/epoch - 3ms/step
# Epoch 69/100
# 1039/1039 - 3s - loss: 3.4124e-05 - 3s/epoch - 3ms/step
# Epoch 70/100
# 1039/1039 - 3s - loss: 2.3039e-05 - 3s/epoch - 3ms/step
# Epoch 71/100
# 1039/1039 - 3s - loss: 1.3349e-05 - 3s/epoch - 3ms/step
# Epoch 72/100
# 1039/1039 - 3s - loss: 1.4972e-05 - 3s/epoch - 3ms/step
# Epoch 73/100
# 1039/1039 - 3s - loss: 3.5936e-05 - 3s/epoch - 3ms/step
# Epoch 74/100
# 1039/1039 - 3s - loss: 3.2445e-05 - 3s/epoch - 3ms/step
# Epoch 75/100
# 1039/1039 - 3s - loss: 1.4822e-05 - 3s/epoch - 3ms/step
# Epoch 76/100
# 1039/1039 - 3s - loss: 4.2820e-05 - 3s/epoch - 3ms/step
# Epoch 77/100
# 1039/1039 - 3s - loss: 3.0987e-05 - 3s/epoch - 3ms/step
# Epoch 78/100
# 1039/1039 - 3s - loss: 1.8056e-05 - 3s/epoch - 3ms/step
# Epoch 79/100
# 1039/1039 - 3s - loss: 2.0112e-05 - 3s/epoch - 3ms/step
# Epoch 80/100
# 1039/1039 - 3s - loss: 1.3543e-05 - 3s/epoch - 3ms/step
# Epoch 81/100
# 1039/1039 - 3s - loss: 2.5395e-05 - 3s/epoch - 3ms/step
# Epoch 82/100
# 1039/1039 - 3s - loss: 1.6320e-05 - 3s/epoch - 3ms/step
# Epoch 83/100
# 1039/1039 - 3s - loss: 1.3714e-05 - 3s/epoch - 3ms/step
# Epoch 84/100
# 1039/1039 - 3s - loss: 2.4334e-05 - 3s/epoch - 3ms/step
# Epoch 85/100
# 1039/1039 - 3s - loss: 2.4334e-05 - 3s/epoch - 3ms/step
# Epoch 86/100
# 1039/1039 - 3s - loss: 1.5444e-05 - 3s/epoch - 3ms/step
# Epoch 87/100
# 1039/1039 - 3s - loss: 1.0749e-05 - 3s/epoch - 3ms/step
# Epoch 88/100
# 1039/1039 - 3s - loss: 1.8159e-05 - 3s/epoch - 3ms/step
# Epoch 89/100
# 1039/1039 - 3s - loss: 1.1986e-05 - 3s/epoch - 3ms/step
# Epoch 90/100
# 1039/1039 - 3s - loss: 2.2975e-05 - 3s/epoch - 3ms/step
# Epoch 91/100
# 1039/1039 - 3s - loss: 3.2044e-05 - 3s/epoch - 3ms/step
# Epoch 92/100
# 1039/1039 - 3s - loss: 4.3580e-05 - 3s/epoch - 3ms/step
# Epoch 93/100
# 1039/1039 - 3s - loss: 1.1213e-05 - 3s/epoch - 3ms/step
# Epoch 94/100
# 1039/1039 - 3s - loss: 1.5918e-05 - 3s/epoch - 3ms/step
# Epoch 95/100
# 1039/1039 - 3s - loss: 2.5663e-05 - 3s/epoch - 3ms/step
# Epoch 96/100
# 1039/1039 - 3s - loss: 2.4834e-05 - 3s/epoch - 3ms/step
# Epoch 97/100
# 1039/1039 - 4s - loss: 1.6403e-05 - 4s/epoch - 3ms/step
# Epoch 98/100
# 1039/1039 - 3s - loss: 6.3964e-05 - 3s/epoch - 3ms/step
# Epoch 99/100
# 1039/1039 - 3s - loss: 4.8777e-05 - 3s/epoch - 3ms/step
# Epoch 100/100
# 1039/1039 - 3s - loss: 1.3853e-05 - 3s/epoch - 3ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 0s 3ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 2.32
# Test RMSE: 6.06

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_2.5.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0     [125.41000366210938]  [125.34671783447266]
# 1       [95.2699966430664]   [94.13567352294922]
# 2                   [81.5]   [79.99317932128906]
# 3      [88.87000274658203]   [87.55306243896484]
# 4      [91.47000122070312]   [90.22528076171875]
# ...                    ...                   ...
# 1034    [65.7699966430664]   [63.93341827392578]
# 1035   [49.08000183105469]  [47.010643005371094]
# 1036   [49.40999984741211]   [47.34403610229492]
# 1037   [40.36000061035156]   [38.21891784667969]
# 1038  [35.689998626708984]   [33.52498245239258]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_2.5_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0    [30.920000076293945]  [28.741132736206055]
# 1      [28.1299991607666]  [25.948047637939453]
# 2     [38.45000076293945]   [36.29789733886719]
# 3     [51.64999771118164]       [49.6083984375]
# 4      [64.9800033569336]   [63.12964630126953]
# ..                    ...                   ...
# 507   [13.50999927520752]  [11.373584747314453]
# 508  [15.460000038146973]  [13.311448097229004]
# 509  [14.649999618530273]  [12.506261825561523]
# 510  [10.579999923706055]    [8.46539306640625]
# 511  [12.010001182556152]   [9.884215354919434]
#
# [512 rows x 2 columns]

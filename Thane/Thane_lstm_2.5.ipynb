# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Thane_lstm_2.5.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 6s - loss: 0.0012 - 6s/epoch - 6ms/step
# Epoch 2/100
# 1039/1039 - 4s - loss: 7.8148e-04 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1039/1039 - 4s - loss: 4.1360e-04 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1039/1039 - 4s - loss: 1.8172e-04 - 4s/epoch - 4ms/step
# Epoch 5/100
# 1039/1039 - 4s - loss: 5.2532e-05 - 4s/epoch - 4ms/step
# Epoch 6/100
# 1039/1039 - 4s - loss: 6.6368e-05 - 4s/epoch - 4ms/step
# Epoch 7/100
# 1039/1039 - 4s - loss: 1.9457e-05 - 4s/epoch - 4ms/step
# Epoch 8/100
# 1039/1039 - 4s - loss: 3.1087e-05 - 4s/epoch - 4ms/step
# Epoch 9/100
# 1039/1039 - 4s - loss: 6.5208e-05 - 4s/epoch - 4ms/step
# Epoch 10/100
# 1039/1039 - 4s - loss: 1.4318e-05 - 4s/epoch - 4ms/step
# Epoch 11/100
# 1039/1039 - 4s - loss: 2.1236e-05 - 4s/epoch - 4ms/step
# Epoch 12/100
# 1039/1039 - 4s - loss: 7.3328e-06 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1039/1039 - 4s - loss: 4.9048e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 1039/1039 - 4s - loss: 2.0291e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 1039/1039 - 4s - loss: 4.4082e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 1039/1039 - 4s - loss: 2.1732e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1039/1039 - 4s - loss: 3.7797e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 1039/1039 - 4s - loss: 4.2710e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 1039/1039 - 4s - loss: 3.2522e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 1039/1039 - 4s - loss: 3.7168e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 1039/1039 - 4s - loss: 1.8410e-05 - 4s/epoch - 4ms/step
# Epoch 22/100
# 1039/1039 - 4s - loss: 8.7764e-05 - 4s/epoch - 4ms/step
# Epoch 23/100
# 1039/1039 - 5s - loss: 2.9489e-05 - 5s/epoch - 5ms/step
# Epoch 24/100
# 1039/1039 - 5s - loss: 6.5493e-05 - 5s/epoch - 5ms/step
# Epoch 25/100
# 1039/1039 - 5s - loss: 2.1972e-05 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1039/1039 - 5s - loss: 4.3072e-05 - 5s/epoch - 5ms/step
# Epoch 27/100
# 1039/1039 - 5s - loss: 1.8846e-05 - 5s/epoch - 4ms/step
# Epoch 28/100
# 1039/1039 - 5s - loss: 2.5414e-05 - 5s/epoch - 4ms/step
# Epoch 29/100
# 1039/1039 - 5s - loss: 2.5269e-05 - 5s/epoch - 5ms/step
# Epoch 30/100
# 1039/1039 - 5s - loss: 1.3024e-05 - 5s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 5s - loss: 1.5258e-05 - 5s/epoch - 5ms/step
# Epoch 32/100
# 1039/1039 - 5s - loss: 5.8731e-06 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1039/1039 - 5s - loss: 6.0632e-05 - 5s/epoch - 4ms/step
# Epoch 34/100
# 1039/1039 - 5s - loss: 5.1163e-05 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1039/1039 - 5s - loss: 4.3964e-05 - 5s/epoch - 4ms/step
# Epoch 36/100
# 1039/1039 - 5s - loss: 6.2612e-06 - 5s/epoch - 5ms/step
# Epoch 37/100
# 1039/1039 - 5s - loss: 2.2471e-05 - 5s/epoch - 4ms/step
# Epoch 38/100
# 1039/1039 - 5s - loss: 2.8737e-05 - 5s/epoch - 5ms/step
# Epoch 39/100
# 1039/1039 - 5s - loss: 3.2481e-05 - 5s/epoch - 4ms/step
# Epoch 40/100
# 1039/1039 - 4s - loss: 2.7181e-05 - 4s/epoch - 4ms/step
# Epoch 41/100
# 1039/1039 - 5s - loss: 2.7701e-05 - 5s/epoch - 4ms/step
# Epoch 42/100
# 1039/1039 - 5s - loss: 2.4447e-05 - 5s/epoch - 5ms/step
# Epoch 43/100
# 1039/1039 - 5s - loss: 3.6561e-05 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1039/1039 - 5s - loss: 4.7582e-05 - 5s/epoch - 5ms/step
# Epoch 45/100
# 1039/1039 - 5s - loss: 7.7821e-06 - 5s/epoch - 4ms/step
# Epoch 46/100
# 1039/1039 - 5s - loss: 5.7068e-05 - 5s/epoch - 5ms/step
# Epoch 47/100
# 1039/1039 - 5s - loss: 5.8696e-05 - 5s/epoch - 5ms/step
# Epoch 48/100
# 1039/1039 - 5s - loss: 1.0213e-05 - 5s/epoch - 4ms/step
# Epoch 49/100
# 1039/1039 - 5s - loss: 6.5325e-06 - 5s/epoch - 5ms/step
# Epoch 50/100
# 1039/1039 - 6s - loss: 1.6079e-05 - 6s/epoch - 6ms/step
# Epoch 51/100
# 1039/1039 - 5s - loss: 2.0236e-05 - 5s/epoch - 4ms/step
# Epoch 52/100
# 1039/1039 - 5s - loss: 2.8406e-05 - 5s/epoch - 4ms/step
# Epoch 53/100
# 1039/1039 - 5s - loss: 1.0552e-05 - 5s/epoch - 5ms/step
# Epoch 54/100
# 1039/1039 - 5s - loss: 2.9099e-05 - 5s/epoch - 4ms/step
# Epoch 55/100
# 1039/1039 - 6s - loss: 6.5890e-06 - 6s/epoch - 5ms/step
# Epoch 56/100
# 1039/1039 - 7s - loss: 6.3446e-05 - 7s/epoch - 6ms/step
# Epoch 57/100
# 1039/1039 - 6s - loss: 4.8335e-06 - 6s/epoch - 6ms/step
# Epoch 58/100
# 1039/1039 - 7s - loss: 7.2168e-06 - 7s/epoch - 6ms/step
# Epoch 59/100
# 1039/1039 - 8s - loss: 1.2435e-04 - 8s/epoch - 8ms/step
# Epoch 60/100
# 1039/1039 - 5s - loss: 1.1395e-05 - 5s/epoch - 4ms/step
# Epoch 61/100
# 1039/1039 - 4s - loss: 2.6721e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 1039/1039 - 4s - loss: 3.4674e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 1039/1039 - 4s - loss: 1.4557e-05 - 4s/epoch - 4ms/step
# Epoch 64/100
# 1039/1039 - 4s - loss: 4.1988e-05 - 4s/epoch - 4ms/step
# Epoch 65/100
# 1039/1039 - 4s - loss: 2.0071e-05 - 4s/epoch - 4ms/step
# Epoch 66/100
# 1039/1039 - 4s - loss: 8.9322e-06 - 4s/epoch - 4ms/step
# Epoch 67/100
# 1039/1039 - 4s - loss: 1.0599e-05 - 4s/epoch - 4ms/step
# Epoch 68/100
# 1039/1039 - 4s - loss: 2.5799e-05 - 4s/epoch - 4ms/step
# Epoch 69/100
# 1039/1039 - 5s - loss: 3.9539e-05 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1039/1039 - 4s - loss: 3.1146e-05 - 4s/epoch - 4ms/step
# Epoch 71/100
# 1039/1039 - 5s - loss: 3.6183e-05 - 5s/epoch - 4ms/step
# Epoch 72/100
# 1039/1039 - 6s - loss: 1.4711e-05 - 6s/epoch - 6ms/step
# Epoch 73/100
# 1039/1039 - 5s - loss: 1.1455e-05 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1039/1039 - 5s - loss: 1.2075e-05 - 5s/epoch - 5ms/step
# Epoch 75/100
# 1039/1039 - 6s - loss: 1.7154e-05 - 6s/epoch - 5ms/step
# Epoch 76/100
# 1039/1039 - 6s - loss: 6.1609e-05 - 6s/epoch - 6ms/step
# Epoch 77/100
# 1039/1039 - 5s - loss: 2.8779e-05 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1039/1039 - 5s - loss: 1.6675e-05 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1039/1039 - 5s - loss: 3.5231e-05 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1039/1039 - 5s - loss: 3.3169e-05 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1039/1039 - 5s - loss: 1.6003e-05 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1039/1039 - 4s - loss: 2.7590e-05 - 4s/epoch - 4ms/step
# Epoch 83/100
# 1039/1039 - 5s - loss: 1.7782e-05 - 5s/epoch - 5ms/step
# Epoch 84/100
# 1039/1039 - 5s - loss: 2.6661e-05 - 5s/epoch - 5ms/step
# Epoch 85/100
# 1039/1039 - 5s - loss: 1.9011e-05 - 5s/epoch - 4ms/step
# Epoch 86/100
# 1039/1039 - 5s - loss: 2.4341e-05 - 5s/epoch - 5ms/step
# Epoch 87/100
# 1039/1039 - 5s - loss: 5.3176e-06 - 5s/epoch - 4ms/step
# Epoch 88/100
# 1039/1039 - 5s - loss: 1.0078e-05 - 5s/epoch - 5ms/step
# Epoch 89/100
# 1039/1039 - 4s - loss: 7.6646e-06 - 4s/epoch - 4ms/step
# Epoch 90/100
# 1039/1039 - 6s - loss: 1.3551e-05 - 6s/epoch - 6ms/step
# Epoch 91/100
# 1039/1039 - 6s - loss: 2.9494e-05 - 6s/epoch - 6ms/step
# Epoch 92/100
# 1039/1039 - 5s - loss: 3.7082e-05 - 5s/epoch - 4ms/step
# Epoch 93/100
# 1039/1039 - 5s - loss: 3.6723e-05 - 5s/epoch - 5ms/step
# Epoch 94/100
# 1039/1039 - 6s - loss: 6.0448e-06 - 6s/epoch - 5ms/step
# Epoch 95/100
# 1039/1039 - 5s - loss: 2.1656e-05 - 5s/epoch - 5ms/step
# Epoch 96/100
# 1039/1039 - 4s - loss: 1.0124e-05 - 4s/epoch - 4ms/step
# Epoch 97/100
# 1039/1039 - 4s - loss: 1.8639e-05 - 4s/epoch - 4ms/step
# Epoch 98/100
# 1039/1039 - 5s - loss: 1.2082e-05 - 5s/epoch - 5ms/step
# Epoch 99/100
# 1039/1039 - 4s - loss: 3.5055e-05 - 4s/epoch - 4ms/step
# Epoch 100/100
# 1039/1039 - 4s - loss: 3.2481e-05 - 4s/epoch - 4ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.66
# Test RMSE: 0.40

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_2.5.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0      [92.69000244140625]   [93.37887573242188]
# 1      [87.20999908447266]    [87.8077392578125]
# 2     [102.52999877929688]  [103.41413879394531]
# 3      [103.5999984741211]  [104.50772857666016]
# 4       [94.8499984741211]   [95.57831573486328]
# ...                    ...                   ...
# 1034   [68.89774322509766]   [69.28915405273438]
# 1035   [68.89774322509766]   [69.28915405273438]
# 1036   [68.89774322509766]   [69.28915405273438]
# 1037   [68.89774322509766]   [69.28915405273438]
# 1038   [68.89774322509766]   [69.28915405273438]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_2.5_test.xlsx')
df
# Out:
#                   Actual  Predicted from lstm
# 0    [68.89774322509766]  [69.28915405273438]
# 1    [68.89774322509766]  [69.28915405273438]
# 2    [68.89774322509766]  [69.28915405273438]
# 3    [68.89774322509766]  [69.28915405273438]
# 4    [68.89774322509766]  [69.28915405273438]
# ..                   ...                  ...
# 507  [68.89774322509766]  [69.28915405273438]
# 508  [68.89774322509766]  [69.28915405273438]
# 509  [68.89774322509766]  [69.28915405273438]
# 510  [68.89774322509766]  [69.28915405273438]
# 511  [68.89774322509766]  [69.28915405273438]
#
# [512 rows x 2 columns]

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
dataset = pd.read_csv('Thane_lstm_10.csv')
data = dataset.values
data = data.astype('float32')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

# %%
# Split data into training and testing sets
train_size = int(len(data) * 0.67)
test_size = len(data) - train_size
train, test = data[0:train_size,:], data[train_size:len(data),:]

# %%
# Create function to create LSTM model
def create_model():
    model = Sequential()
    model.add(LSTM(50, input_shape=(1, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
# Reshape input data to be 3-dimensional
X_train = np.reshape(train, (train.shape[0], 1, train.shape[1]))
X_test = np.reshape(test, (test.shape[0], 1, test.shape[1]))

# %%
# Create and fit the LSTM model
model = create_model()
model.fit(X_train, train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1039/1039 - 8s - loss: 0.0023 - 8s/epoch - 8ms/step
# Epoch 2/100
# 1039/1039 - 4s - loss: 1.1203e-04 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1039/1039 - 4s - loss: 8.6621e-05 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1039/1039 - 4s - loss: 9.1837e-05 - 4s/epoch - 4ms/step
# Epoch 5/100
# 1039/1039 - 4s - loss: 6.4714e-05 - 4s/epoch - 4ms/step
# Epoch 6/100
# 1039/1039 - 4s - loss: 5.3414e-05 - 4s/epoch - 4ms/step
# Epoch 7/100
# 1039/1039 - 4s - loss: 6.5145e-05 - 4s/epoch - 4ms/step
# Epoch 8/100
# 1039/1039 - 4s - loss: 6.8120e-05 - 4s/epoch - 4ms/step
# Epoch 9/100
# 1039/1039 - 4s - loss: 6.3383e-05 - 4s/epoch - 4ms/step
# Epoch 10/100
# 1039/1039 - 4s - loss: 4.4799e-05 - 4s/epoch - 4ms/step
# Epoch 11/100
# 1039/1039 - 4s - loss: 6.0613e-05 - 4s/epoch - 4ms/step
# Epoch 12/100
# 1039/1039 - 4s - loss: 5.3324e-05 - 4s/epoch - 4ms/step
# Epoch 13/100
# 1039/1039 - 4s - loss: 6.0818e-05 - 4s/epoch - 4ms/step
# Epoch 14/100
# 1039/1039 - 4s - loss: 4.5983e-05 - 4s/epoch - 4ms/step
# Epoch 15/100
# 1039/1039 - 4s - loss: 4.7134e-05 - 4s/epoch - 4ms/step
# Epoch 16/100
# 1039/1039 - 4s - loss: 4.6782e-05 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1039/1039 - 4s - loss: 4.9470e-05 - 4s/epoch - 4ms/step
# Epoch 18/100
# 1039/1039 - 4s - loss: 5.2574e-05 - 4s/epoch - 4ms/step
# Epoch 19/100
# 1039/1039 - 4s - loss: 4.5989e-05 - 4s/epoch - 4ms/step
# Epoch 20/100
# 1039/1039 - 4s - loss: 4.7014e-05 - 4s/epoch - 4ms/step
# Epoch 21/100
# 1039/1039 - 5s - loss: 5.0302e-05 - 5s/epoch - 4ms/step
# Epoch 22/100
# 1039/1039 - 5s - loss: 5.2639e-05 - 5s/epoch - 5ms/step
# Epoch 23/100
# 1039/1039 - 5s - loss: 5.1531e-05 - 5s/epoch - 5ms/step
# Epoch 24/100
# 1039/1039 - 5s - loss: 4.7484e-05 - 5s/epoch - 5ms/step
# Epoch 25/100
# 1039/1039 - 5s - loss: 5.5932e-05 - 5s/epoch - 5ms/step
# Epoch 26/100
# 1039/1039 - 5s - loss: 5.3526e-05 - 5s/epoch - 5ms/step
# Epoch 27/100
# 1039/1039 - 5s - loss: 5.1094e-05 - 5s/epoch - 5ms/step
# Epoch 28/100
# 1039/1039 - 5s - loss: 4.6599e-05 - 5s/epoch - 5ms/step
# Epoch 29/100
# 1039/1039 - 5s - loss: 4.4808e-05 - 5s/epoch - 5ms/step
# Epoch 30/100
# 1039/1039 - 5s - loss: 5.0186e-05 - 5s/epoch - 4ms/step
# Epoch 31/100
# 1039/1039 - 5s - loss: 4.9320e-05 - 5s/epoch - 5ms/step
# Epoch 32/100
# 1039/1039 - 5s - loss: 4.6619e-05 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1039/1039 - 5s - loss: 4.3957e-05 - 5s/epoch - 5ms/step
# Epoch 34/100
# 1039/1039 - 5s - loss: 4.4737e-05 - 5s/epoch - 5ms/step
# Epoch 35/100
# 1039/1039 - 5s - loss: 5.1592e-05 - 5s/epoch - 5ms/step
# Epoch 36/100
# 1039/1039 - 5s - loss: 5.1775e-05 - 5s/epoch - 5ms/step
# Epoch 37/100
# 1039/1039 - 5s - loss: 5.4922e-05 - 5s/epoch - 4ms/step
# Epoch 38/100
# 1039/1039 - 4s - loss: 5.2929e-05 - 4s/epoch - 4ms/step
# Epoch 39/100
# 1039/1039 - 5s - loss: 4.6850e-05 - 5s/epoch - 4ms/step
# Epoch 40/100
# 1039/1039 - 5s - loss: 4.3131e-05 - 5s/epoch - 5ms/step
# Epoch 41/100
# 1039/1039 - 5s - loss: 4.3634e-05 - 5s/epoch - 5ms/step
# Epoch 42/100
# 1039/1039 - 5s - loss: 4.6392e-05 - 5s/epoch - 4ms/step
# Epoch 43/100
# 1039/1039 - 5s - loss: 4.7271e-05 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1039/1039 - 5s - loss: 4.2772e-05 - 5s/epoch - 5ms/step
# Epoch 45/100
# 1039/1039 - 5s - loss: 4.1138e-05 - 5s/epoch - 5ms/step
# Epoch 46/100
# 1039/1039 - 5s - loss: 5.2228e-05 - 5s/epoch - 4ms/step
# Epoch 47/100
# 1039/1039 - 5s - loss: 3.9873e-05 - 5s/epoch - 5ms/step
# Epoch 48/100
# 1039/1039 - 6s - loss: 5.0479e-05 - 6s/epoch - 6ms/step
# Epoch 49/100
# 1039/1039 - 5s - loss: 4.0010e-05 - 5s/epoch - 5ms/step
# Epoch 50/100
# 1039/1039 - 5s - loss: 5.3295e-05 - 5s/epoch - 5ms/step
# Epoch 51/100
# 1039/1039 - 5s - loss: 4.6024e-05 - 5s/epoch - 5ms/step
# Epoch 52/100
# 1039/1039 - 5s - loss: 4.9175e-05 - 5s/epoch - 5ms/step
# Epoch 53/100
# 1039/1039 - 6s - loss: 5.0669e-05 - 6s/epoch - 6ms/step
# Epoch 54/100
# 1039/1039 - 6s - loss: 4.7971e-05 - 6s/epoch - 6ms/step
# Epoch 55/100
# 1039/1039 - 6s - loss: 4.1505e-05 - 6s/epoch - 6ms/step
# Epoch 56/100
# 1039/1039 - 7s - loss: 4.2266e-05 - 7s/epoch - 7ms/step
# Epoch 57/100
# 1039/1039 - 8s - loss: 4.7779e-05 - 8s/epoch - 7ms/step
# Epoch 58/100
# 1039/1039 - 5s - loss: 4.0561e-05 - 5s/epoch - 4ms/step
# Epoch 59/100
# 1039/1039 - 4s - loss: 5.0097e-05 - 4s/epoch - 4ms/step
# Epoch 60/100
# 1039/1039 - 4s - loss: 5.0413e-05 - 4s/epoch - 4ms/step
# Epoch 61/100
# 1039/1039 - 4s - loss: 4.6640e-05 - 4s/epoch - 4ms/step
# Epoch 62/100
# 1039/1039 - 4s - loss: 5.0996e-05 - 4s/epoch - 4ms/step
# Epoch 63/100
# 1039/1039 - 4s - loss: 4.6644e-05 - 4s/epoch - 4ms/step
# Epoch 64/100
# 1039/1039 - 4s - loss: 4.2403e-05 - 4s/epoch - 4ms/step
# Epoch 65/100
# 1039/1039 - 4s - loss: 4.9711e-05 - 4s/epoch - 4ms/step
# Epoch 66/100
# 1039/1039 - 5s - loss: 4.3705e-05 - 5s/epoch - 5ms/step
# Epoch 67/100
# 1039/1039 - 5s - loss: 4.8860e-05 - 5s/epoch - 5ms/step
# Epoch 68/100
# 1039/1039 - 5s - loss: 5.1035e-05 - 5s/epoch - 5ms/step
# Epoch 69/100
# 1039/1039 - 5s - loss: 4.0841e-05 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1039/1039 - 6s - loss: 4.0018e-05 - 6s/epoch - 5ms/step
# Epoch 71/100
# 1039/1039 - 6s - loss: 4.5092e-05 - 6s/epoch - 5ms/step
# Epoch 72/100
# 1039/1039 - 6s - loss: 3.8322e-05 - 6s/epoch - 5ms/step
# Epoch 73/100
# 1039/1039 - 5s - loss: 4.3629e-05 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1039/1039 - 6s - loss: 4.6582e-05 - 6s/epoch - 6ms/step
# Epoch 75/100
# 1039/1039 - 5s - loss: 5.4761e-05 - 5s/epoch - 4ms/step
# Epoch 76/100
# 1039/1039 - 5s - loss: 4.5179e-05 - 5s/epoch - 5ms/step
# Epoch 77/100
# 1039/1039 - 5s - loss: 4.8473e-05 - 5s/epoch - 4ms/step
# Epoch 78/100
# 1039/1039 - 6s - loss: 3.6551e-05 - 6s/epoch - 5ms/step
# Epoch 79/100
# 1039/1039 - 5s - loss: 4.7109e-05 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1039/1039 - 5s - loss: 3.6584e-05 - 5s/epoch - 4ms/step
# Epoch 81/100
# 1039/1039 - 5s - loss: 4.0240e-05 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1039/1039 - 5s - loss: 4.7580e-05 - 5s/epoch - 5ms/step
# Epoch 83/100
# 1039/1039 - 5s - loss: 4.2680e-05 - 5s/epoch - 5ms/step
# Epoch 84/100
# 1039/1039 - 5s - loss: 4.1012e-05 - 5s/epoch - 5ms/step
# Epoch 85/100
# 1039/1039 - 5s - loss: 4.1140e-05 - 5s/epoch - 5ms/step
# Epoch 86/100
# 1039/1039 - 5s - loss: 5.6030e-05 - 5s/epoch - 4ms/step
# Epoch 87/100
# 1039/1039 - 6s - loss: 4.4552e-05 - 6s/epoch - 5ms/step
# Epoch 88/100
# 1039/1039 - 6s - loss: 4.4394e-05 - 6s/epoch - 6ms/step
# Epoch 89/100
# 1039/1039 - 6s - loss: 4.6115e-05 - 6s/epoch - 5ms/step
# Epoch 90/100
# 1039/1039 - 4s - loss: 4.3062e-05 - 4s/epoch - 4ms/step
# Epoch 91/100
# 1039/1039 - 6s - loss: 3.9210e-05 - 6s/epoch - 6ms/step
# Epoch 92/100
# 1039/1039 - 5s - loss: 5.5744e-05 - 5s/epoch - 5ms/step
# Epoch 93/100
# 1039/1039 - 4s - loss: 4.0385e-05 - 4s/epoch - 4ms/step
# Epoch 94/100
# 1039/1039 - 4s - loss: 5.0265e-05 - 4s/epoch - 4ms/step
# Epoch 95/100
# 1039/1039 - 5s - loss: 4.0249e-05 - 5s/epoch - 5ms/step
# Epoch 96/100
# 1039/1039 - 4s - loss: 4.1337e-05 - 4s/epoch - 4ms/step
# Epoch 97/100
# 1039/1039 - 4s - loss: 4.3147e-05 - 4s/epoch - 4ms/step
# Epoch 98/100
# 1039/1039 - 4s - loss: 5.0438e-05 - 4s/epoch - 4ms/step
# Epoch 99/100
# 1039/1039 - 4s - loss: 4.4845e-05 - 4s/epoch - 4ms/step
# Epoch 100/100
# 1039/1039 - 5s - loss: 4.6678e-05 - 5s/epoch - 5ms/step

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 33/33 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
train = scaler.inverse_transform(train)
test_predict = scaler.inverse_transform(test_predict)
test = scaler.inverse_transform(test)

# %%
train_rmse = np.sqrt(np.mean(np.power((train - train_predict), 2)))
test_rmse = np.sqrt(np.mean(np.power((test - test_predict), 2)))
print('Train RMSE: %.2f' % train_rmse)
print('Test RMSE: %.2f' % test_rmse)
# Out:
# Train RMSE: 0.56
# Test RMSE: 2.84

# %%
df=pd.DataFrame({'Actual':train.tolist(),'Predicted from lstm':train_predict.tolist()})
df.to_excel('lstm_10.xlsx')
df
# Out:
#                     Actual   Predicted from lstm
# 0     [253.96002197265625]  [254.23175048828125]
# 1     [245.72000122070312]   [245.9630889892578]
# 2     [346.07000732421875]   [346.2355651855469]
# 3                  [272.5]   [272.8179626464844]
# 4      [335.1199951171875]   [335.3493957519531]
# ...                    ...                   ...
# 1034  [229.55999755859375]  [229.73477172851562]
# 1035   [295.0299987792969]  [295.36444091796875]
# 1036   [302.7799987792969]   [303.1085205078125]
# 1037   [260.3299865722656]   [260.6205749511719]
# 1038  [256.04998779296875]   [256.3282165527344]
#
# [1039 rows x 2 columns]

# %%
df=pd.DataFrame({'Actual':test.tolist(),'Predicted from lstm':test_predict.tolist()})
df.to_excel('lstm_10_test.xlsx')
df
# Out:
#                    Actual   Predicted from lstm
# 0    [187.19000244140625]    [187.131103515625]
# 1    [112.83999633789062]  [112.33479309082031]
# 2    [149.52999877929688]  [149.23594665527344]
# 3                [210.75]  [210.82870483398438]
# 4                [282.75]   [283.0813293457031]
# ..                    ...                   ...
# 507  [100.41999816894531]   [99.85447692871094]
# 508  [124.25886535644531]  [123.81503295898438]
# 509  [124.25886535644531]  [123.81503295898438]
# 510  [124.25886535644531]  [123.81503295898438]
# 511  [124.25886535644531]  [123.81503295898438]
#
# [512 rows x 2 columns]
